# %%
import pandas as pd
import tensorflow as tf

from autogluon.tabular import TabularPredictor

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
gpus = len(tf.config.list_physical_devices('GPU'))
cpus = len(tf.config.list_physical_devices('CPU'))

print(gpus, cpus)
# Out:
# 1 1

# %%
train_df.head(2)
# Out:
#    id  person_age  person_income person_home_ownership  person_emp_length  \
# 0   0          37          35000                  RENT                0.0
# 1   1          22          56000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0   EDUCATION          B       6000          11.49                 0.17
# 1     MEDICAL          C       4000          13.35                 0.07
#
#   cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# 0                         N                          14            0
# 1                         N                           2            0

# %%
test_df.head(2)
# Out:
#       id  person_age  person_income person_home_ownership  person_emp_length  \
# 0  58645          23          69000                  RENT                3.0
# 1  58646          26          96000              MORTGAGE                6.0
#
#        loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0  HOMEIMPROVEMENT          F      25000          15.76                 0.36
# 1         PERSONAL          C      10000          12.68                 0.10
#
#   cb_person_default_on_file  cb_person_cred_hist_length
# 0                         N                           2
# 1                         Y                           4

# %%
train_df['loan_status'].nunique()
# Out:
# 2

# %%
# Train the AutoGluon TabularPredictor
# Set up the TabularPredictor with GPU and memory optimization
predictor = TabularPredictor(
    label='loan_status',
    eval_metric='roc_auc',
    problem_type='binary'
).fit(
    train_df,
    presets='best_quality',
    time_limit=3600 * 11,
    verbosity=2,
    excluded_model_types=['KNN'],
    ag_args_fit={'num_cpus': 10, 'num_gpus': 0, 'memory_ratio': 0.8}
)

# Summarize results
results = predictor.fit_summary()
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20241004_153801"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.8.19
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          20
# Memory Avail:       25.72 GB / 31.82 GB (80.8%)
# Disk Space Avail:   683.71 GB / 953.00 GB (71.7%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 9900s of the 39600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-10-04 19:38:03,468	INFO worker.py:1752 -- Started a local Ray instance.
# 		Context path: "AutogluonModels\ag-20241004_153801\ds_sub_fit\sub_fit_ho"
# (_dystack pid=17672) Running DyStack sub-fit ...
# (_dystack pid=17672) Beginning AutoGluon training ... Time limit = 9896s
# (_dystack pid=17672) AutoGluon will save models to "AutogluonModels\ag-20241004_153801\ds_sub_fit\sub_fit_ho"
# (_dystack pid=17672) Train Data Rows:    52128
# (_dystack pid=17672) Train Data Columns: 12
# (_dystack pid=17672) Label Column:       loan_status
# (_dystack pid=17672) Problem Type:       binary
# (_dystack pid=17672) Preprocessing data ...
# (_dystack pid=17672) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=17672) Using Feature Generators to preprocess the data ...
# (_dystack pid=17672) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=17672) 	Available Memory:                    25262.20 MB
# (_dystack pid=17672) 	Train Data (Original)  Memory Usage: 15.39 MB (0.1% of available memory)
# (_dystack pid=17672) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=17672) 	Stage 1 Generators:
# (_dystack pid=17672) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=17672) 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=17672) 	Stage 2 Generators:
# (_dystack pid=17672) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=17672) 	Stage 3 Generators:
# (_dystack pid=17672) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=17672) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=17672) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=17672) 	Stage 4 Generators:
# (_dystack pid=17672) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=17672) 	Stage 5 Generators:
# (_dystack pid=17672) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=17672) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=17672) 		('float', [])  : 3 | ['person_emp_length', 'loan_int_rate', 'loan_percent_income']
# (_dystack pid=17672) 		('int', [])    : 5 | ['id', 'person_age', 'person_income', 'loan_amnt', 'cb_person_cred_hist_length']
# (_dystack pid=17672) 		('object', []) : 4 | ['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file']
# (_dystack pid=17672) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=17672) 		('category', [])  : 3 | ['person_home_ownership', 'loan_intent', 'loan_grade']
# (_dystack pid=17672) 		('float', [])     : 3 | ['person_emp_length', 'loan_int_rate', 'loan_percent_income']
# (_dystack pid=17672) 		('int', [])       : 5 | ['id', 'person_age', 'person_income', 'loan_amnt', 'cb_person_cred_hist_length']
# (_dystack pid=17672) 		('int', ['bool']) : 1 | ['cb_person_default_on_file']
# (_dystack pid=17672) 	0.1s = Fit runtime
# (_dystack pid=17672) 	12 features in original data used to generate 12 features in processed data.
# (_dystack pid=17672) 	Train Data (Processed) Memory Usage: 3.38 MB (0.0% of available memory)
# (_dystack pid=17672) Data preprocessing and feature engineering runtime = 0.15s ...
# (_dystack pid=17672) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=17672) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=17672) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=17672) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=17672) User-specified model hyperparameters to be fit:
# (_dystack pid=17672) {
# (_dystack pid=17672) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=17672) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=17672) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=17672) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=17672) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=17672) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=17672) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=17672) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=17672) }
# (_dystack pid=17672) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=17672) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=17672) Fitting 108 L1 models ...
# (_dystack pid=17672) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 6595.41s of the 9895.59s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.11%)
# (_ray_fit pid=2796) [1000]	valid_set's binary_logloss: 0.172249
# (_ray_fit pid=18224) [1000]	valid_set's binary_logloss: 0.163123 [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_dystack pid=17672) 	0.9391	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	13.98s	 = Training   runtime
# (_dystack pid=17672) 	0.41s	 = Validation runtime
# (_dystack pid=17672) Fitting model: LightGBM_BAG_L1 ... Training model for up to 6578.54s of the 9878.71s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.11%)
# (_dystack pid=17672) 	0.9567	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	9.03s	 = Training   runtime
# (_dystack pid=17672) 	0.12s	 = Validation runtime
# (_dystack pid=17672) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 6567.88s of the 9868.05s of remaining time.
# (_dystack pid=17672) 	0.9349	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	2.35s	 = Training   runtime
# (_dystack pid=17672) 	1.07s	 = Validation runtime
# (_dystack pid=17672) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 6564.26s of the 9864.43s of remaining time.
# (_dystack pid=17672) 	0.936	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	2.31s	 = Training   runtime
# (_dystack pid=17672) 	1.02s	 = Validation runtime
# (_dystack pid=17672) Fitting model: CatBoost_BAG_L1 ... Training model for up to 6560.74s of the 9860.91s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.12%)
# (_dystack pid=17672) 	0.9549	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	285.02s	 = Training   runtime
# (_dystack pid=17672) 	0.04s	 = Validation runtime
# (_dystack pid=17672) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 6274.11s of the 9574.28s of remaining time.
# (_dystack pid=17672) 	0.9233	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	1.17s	 = Training   runtime
# (_dystack pid=17672) 	1.24s	 = Validation runtime
# (_dystack pid=17672) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 6271.4s of the 9571.57s of remaining time.
# (_dystack pid=17672) 	0.9236	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	1.09s	 = Training   runtime
# (_dystack pid=17672) 	1.18s	 = Validation runtime
# (_dystack pid=17672) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 6268.84s of the 9569.02s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.17%)
# (_dystack pid=17672) 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training (ImportError)... Skipping this model.
# (_dystack pid=17672) 		ray::_ray_fit() (pid=1948, ip=127.0.0.1)
# (_dystack pid=17672) ModuleNotFoundError: No module named 'fastai'
# (_dystack pid=17672)
# (_dystack pid=17672) During handling of the above exception, another exception occurred:
# (_dystack pid=17672)
# (_dystack pid=17672) ray::_ray_fit() (pid=1948, ip=127.0.0.1)
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=17672)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=17672)     out = self._fit(**kwargs)
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
# (_dystack pid=17672)     try_import_fastai()
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
# (_dystack pid=17672)     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# (_dystack pid=17672) ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# (_dystack pid=17672) Fitting model: XGBoost_BAG_L1 ... Training model for up to 6267.16s of the 9567.33s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.15%)
# (_dystack pid=17672) 	0.9538	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	11.13s	 = Training   runtime
# (_dystack pid=17672) 	0.14s	 = Validation runtime
# (_dystack pid=17672) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 6254.35s of the 9554.52s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.09%)
# (_ray_fit pid=17572) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=17572)   self.model = torch.load(net_filename)
# (_ray_fit pid=9676) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=9676)   self.model = torch.load(net_filename)
# (_ray_fit pid=7536) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=7536)   self.model = torch.load(net_filename)
# (_ray_fit pid=5100) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=5100)   self.model = torch.load(net_filename)
# (_ray_fit pid=1892) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=1892)   self.model = torch.load(net_filename)
# (_ray_fit pid=2680) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=2680)   self.model = torch.load(net_filename)
# (_ray_fit pid=13840) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=13840)   self.model = torch.load(net_filename)
# (_ray_fit pid=15900) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=15900)   self.model = torch.load(net_filename)
# (_dystack pid=17672) 	0.9295	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	200.34s	 = Training   runtime
# (_dystack pid=17672) 	0.21s	 = Validation runtime
# (_dystack pid=17672) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 6052.37s of the 9352.54s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.13%)
# (_dystack pid=17672) 	0.9554	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	10.78s	 = Training   runtime
# (_dystack pid=17672) 	0.14s	 = Validation runtime
# (_dystack pid=17672) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 6039.91s of the 9340.08s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.12%)
# (_dystack pid=17672) 	0.9554	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	36.79s	 = Training   runtime
# (_dystack pid=17672) 	0.05s	 = Validation runtime
# (_dystack pid=17672) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 6001.44s of the 9301.61s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.09%)
# (_ray_fit pid=11280) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=11280)   self.model = torch.load(net_filename)
# (_ray_fit pid=9516) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature. [repeated 2x across cluster]
# (_ray_fit pid=9516)   self.model = torch.load(net_filename) [repeated 2x across cluster]
# (_ray_fit pid=2772) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=2772)   self.model = torch.load(net_filename)
# (_ray_fit pid=14796) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=14796)   self.model = torch.load(net_filename)
# (_ray_fit pid=16804) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=16804)   self.model = torch.load(net_filename)
# (_ray_fit pid=17732) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=17732)   self.model = torch.load(net_filename)
# (_dystack pid=17672) 	0.9314	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	359.99s	 = Training   runtime
# (_dystack pid=17672) 	0.26s	 = Validation runtime
# (_dystack pid=17672) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 5639.77s of the 8939.95s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.12%)
# (_ray_fit pid=8124) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=8124)   self.model = torch.load(net_filename)
# (_ray_fit pid=3020) [1000]	valid_set's binary_logloss: 0.155904 [repeated 3x across cluster]
# (_ray_fit pid=17800) [1000]	valid_set's binary_logloss: 0.150931 [repeated 4x across cluster]
# (_ray_fit pid=14444) [1000]	valid_set's binary_logloss: 0.145277 [repeated 3x across cluster]
# (_dystack pid=17672) 	0.9581	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	17.93s	 = Training   runtime
# (_dystack pid=17672) 	0.68s	 = Validation runtime
# (_dystack pid=17672) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 5620.08s of the 8920.25s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.17%)
# (_dystack pid=17672) 	Warning: Exception caused NeuralNetFastAI_r191_BAG_L1 to fail during training (ImportError)... Skipping this model.
# (_dystack pid=17672) 		ray::_ray_fit() (pid=8296, ip=127.0.0.1)
# (_dystack pid=17672) ModuleNotFoundError: No module named 'fastai'
# (_dystack pid=17672)
# (_dystack pid=17672) During handling of the above exception, another exception occurred:
# (_dystack pid=17672)
# (_dystack pid=17672) ray::_ray_fit() (pid=8296, ip=127.0.0.1)
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=17672)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=17672)     out = self._fit(**kwargs)
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
# (_dystack pid=17672)     try_import_fastai()
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
# (_dystack pid=17672)     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# (_dystack pid=17672) ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# (_dystack pid=17672) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=15076, ip=127.0.0.1)
# (_dystack pid=17672) ModuleNotFoundError: No module named 'fastai'
# (_dystack pid=17672)
# (_dystack pid=17672) During handling of the above exception, another exception occurred:
# (_dystack pid=17672)
# (_dystack pid=17672) ray::_ray_fit() (pid=15076, ip=127.0.0.1)
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
# (_dystack pid=17672)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=17672)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=17672)     out = self._fit(**kwargs)
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
# (_dystack pid=17672)     try_import_fastai()
# (_dystack pid=17672)   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
# (_dystack pid=17672)     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# (_dystack pid=17672) ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# (_dystack pid=17672) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 5618.39s of the 8918.56s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.17%)
# (_dystack pid=17672) 	0.9555	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	128.54s	 = Training   runtime
# (_dystack pid=17672) 	0.08s	 = Validation runtime
# (_dystack pid=17672) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 5488.21s of the 8788.38s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.10%)
# (_ray_fit pid=4608) [1000]	valid_set's binary_logloss: 0.165331 [repeated 3x across cluster]
# (_ray_fit pid=4608) [6000]	valid_set's binary_logloss: 0.152046 [repeated 10x across cluster]
# (_ray_fit pid=15032) [10000]	valid_set's binary_logloss: 0.169684 [repeated 9x across cluster]
# (_ray_fit pid=7408) [1000]	valid_set's binary_logloss: 0.17747 [repeated 2x across cluster]
# (_ray_fit pid=13820) [6000]	valid_set's binary_logloss: 0.164644 [repeated 9x across cluster]
# (_ray_fit pid=7408) [10000]	valid_set's binary_logloss: 0.164911 [repeated 9x across cluster]
# (_ray_fit pid=7588) [2000]	valid_set's binary_logloss: 0.167208 [repeated 4x across cluster]
# (_ray_fit pid=7588) [7000]	valid_set's binary_logloss: 0.160433 [repeated 10x across cluster]
# (_ray_fit pid=8616) [2000]	valid_set's binary_logloss: 0.170612 [repeated 6x across cluster]
# (_ray_fit pid=8616) [7000]	valid_set's binary_logloss: 0.162684 [repeated 8x across cluster]
# (_ray_fit pid=15792) [8000]	valid_set's binary_logloss: 0.164619 [repeated 8x across cluster]
# (_dystack pid=17672) 	0.9418	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	57.94s	 = Training   runtime
# (_dystack pid=17672) 	5.66s	 = Validation runtime
# (_dystack pid=17672) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 5427.8s of the 8727.98s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.09%)
# (_ray_fit pid=5628) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=5628)   self.model = torch.load(net_filename)
# (_ray_fit pid=12380) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=12380)   self.model = torch.load(net_filename)
# (_ray_fit pid=17032) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=17032)   self.model = torch.load(net_filename)
# (_ray_fit pid=9712) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=9712)   self.model = torch.load(net_filename)
# (_ray_fit pid=7464) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=7464)   self.model = torch.load(net_filename)
# (_ray_fit pid=16220) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=16220)   self.model = torch.load(net_filename)
# (_ray_fit pid=1984) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=1984)   self.model = torch.load(net_filename)
# (_dystack pid=17672) 	0.9298	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	312.14s	 = Training   runtime
# (_dystack pid=17672) 	0.26s	 = Validation runtime
# (_dystack pid=17672) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 5114.02s of the 8414.2s of remaining time.
# (_dystack pid=17672) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.27%)
# (_ray_fit pid=16772) C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py:411: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# (_ray_fit pid=16772)   self.model = torch.load(net_filename)
# (_dystack pid=17672) 	0.9536	 = Validation score   (roc_auc)
# (_dystack pid=17672) 	23.03s	 = Training   runtime
# (_dystack pid=17672) 	0.49s	 = Validation runtime
# (_dystack pid=17672) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 5089.29s of the 8389.46s of remaining time.
# (_dystack pid=17672) 	0.9251	 = Validation score   (roc_auc)
# ...
# 	0.9301	 = Validation score   (roc_auc)
# 	379.23s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 2965.29s of the 16532.06s of remaining time.
# 	Ensemble Weights: {'LightGBM_r130_BAG_L1': 0.25, 'CatBoost_r50_BAG_L1': 0.25, 'CatBoost_r5_BAG_L1': 0.208, 'LightGBM_r15_BAG_L1': 0.125, 'CatBoost_r180_BAG_L1': 0.125, 'XGBoost_r22_BAG_L1': 0.042}
# 	0.9607	 = Validation score   (roc_auc)
# 	3.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 13124.24s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 5065.0 rows/s (7331 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20241004_153801")
# *** Summary of fit() ***
# Estimated performance of each model:
#                          model  score_val eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0          WeightedEnsemble_L2   0.960678     roc_auc       1.451754   309.250093                0.004999           3.133026            2       True         86
# 1         CatBoost_r180_BAG_L1   0.958595     roc_auc       0.068146    38.693011                0.068146          38.693011            1       True         69
# 2         LightGBM_r131_BAG_L1   0.958511     roc_auc       0.833196    18.485234                0.833196          18.485234            1       True         13
# 3          CatBoost_r49_BAG_L1   0.958431     roc_auc       0.043605    83.042284                0.043605          83.042284            1       True         43
# 4           CatBoost_r5_BAG_L1   0.958418     roc_auc       0.042999   100.828650                0.042999         100.828650            1       True         55
# 5         LightGBM_r130_BAG_L1   0.958410     roc_auc       0.177996     9.267841                0.177996           9.267841            1       True         25
# 6          LightGBM_r15_BAG_L1   0.958348     roc_auc       0.864683    20.627771                0.864683          20.627771            1       True         39
# 7         CatBoost_r137_BAG_L1   0.958232     roc_auc       0.063996   540.132406                0.063996         540.132406            1       True         19
# 8          CatBoost_r50_BAG_L1   0.958222     roc_auc       0.096000   121.265198                0.096000         121.265198            1       True         27
# 9           CatBoost_r6_BAG_L1   0.958073     roc_auc       0.083581    92.096195                0.083581          92.096195            1       True         67
# 10         CatBoost_r60_BAG_L1   0.957412     roc_auc       0.058940   356.996132                0.058940         356.996132            1       True         63
# 11        LightGBM_r121_BAG_L1   0.957344     roc_auc       0.812647    29.463406                0.812647          29.463406            1       True         68
# 12         CatBoost_r69_BAG_L1   0.957292     roc_auc       0.057858   344.623709                0.057858         344.623709            1       True         30
# 13          XGBoost_r31_BAG_L1   0.957198     roc_auc       1.744386   149.882930                1.744386         149.882930            1       True         61
# 14        LightGBM_r161_BAG_L1   0.957051     roc_auc       0.832026    30.018357                0.832026          30.018357            1       True         32
# 15         CatBoost_r70_BAG_L1   0.957027     roc_auc       0.107002   125.755409                0.107002         125.755409            1       True         33
# 16             LightGBM_BAG_L1   0.956925     roc_auc       0.145258     8.734813                0.145258           8.734813            1       True          2
# 17          XGBoost_r89_BAG_L1   0.956893     roc_auc       0.191000    17.614932                0.191000          17.614932            1       True         23
# 18        CatBoost_r177_BAG_L1   0.956844     roc_auc       0.036671    43.185605                0.036671          43.185605            1       True         11
# 19          XGBoost_r22_BAG_L1   0.956647     roc_auc       0.196931    15.434595                0.196931          15.434595            1       True         66
# 20          XGBoost_r98_BAG_L1   0.956555     roc_auc       1.026305    40.691440                1.026305          40.691440            1       True         38
# 21          CatBoost_r9_BAG_L1   0.956352     roc_auc       0.093998   141.788881                0.093998         141.788881            1       True         14
# 22          XGBoost_r95_BAG_L1   0.956199     roc_auc       0.222002    19.374841                0.222002          19.374841            1       True         81
# 23         CatBoost_r12_BAG_L1   0.956157     roc_auc       0.047995    91.432378                0.047995          91.432378            1       True         74
# 24        CatBoost_r198_BAG_L1   0.956040     roc_auc       0.050003   319.483559                0.050003         319.483559            1       True         79
# 25          XGBoost_r49_BAG_L1   0.956015     roc_auc       0.303003    21.585104                0.303003          21.585104            1       True         54
# 26        LightGBMLarge_BAG_L1   0.955832     roc_auc       0.162997    10.142676                0.162997          10.142676            1       True         10
# 27             CatBoost_BAG_L1   0.955772     roc_auc       0.045999   276.248486                0.045999         276.248486            1       True          5
# 28         XGBoost_r194_BAG_L1   0.955732     roc_auc       0.100159     8.071323                0.100159           8.071323            1       True         28
# 29        CatBoost_r128_BAG_L1   0.955658     roc_auc       0.083465   115.236746                0.083465         115.236746            1       True         50
# 30          XGBoost_r34_BAG_L1   0.955633     roc_auc       0.396532    20.305908                0.396532          20.305908            1       True         82
# 31              XGBoost_BAG_L1   0.955581     roc_auc       0.158199    11.910914                0.158199          11.910914            1       True          8
# 32        CatBoost_r143_BAG_L1   0.955422     roc_auc       0.040005    36.945992                0.040005          36.945992            1       True         58
# 33        CatBoost_r163_BAG_L1   0.955355     roc_auc       0.037996   130.643868                0.037996         130.643868            1       True         78
# 34        LightGBM_r135_BAG_L1   0.955292     roc_auc       0.218002    12.488497                0.218002          12.488497            1       True         65
# 35          XGBoost_r33_BAG_L1   0.954986     roc_auc       0.576495    26.255400                0.576495          26.255400            1       True         17
# 36        LightGBM_r143_BAG_L1   0.954776     roc_auc       0.457999    18.314972                0.457999          18.314972            1       True         45
# 37         CatBoost_r13_BAG_L1   0.954615     roc_auc       0.053071   144.768708                0.053071         144.768708            1       True         20
# 38        CatBoost_r167_BAG_L1   0.954343     roc_auc       0.043063   131.409922                0.043063         131.409922            1       True         36
# 39         CatBoost_r86_BAG_L1   0.952836     roc_auc       0.048046   271.276174                0.048046         271.276174            1       True         41
# 40         LightGBM_r96_BAG_L1   0.943210     roc_auc       5.403110    61.425802                5.403110          61.425802            1       True         15
# 41         LightGBM_r94_BAG_L1   0.943034     roc_auc       3.217877    46.812341                3.217877          46.812341            1       True         48
# 42    RandomForest_r127_BAG_L1   0.942692     roc_auc       1.060807     7.800737                1.060807           7.800737            1       True         46
# 43     RandomForest_r34_BAG_L1   0.942566     roc_auc       0.970992     4.596449                0.970992           4.596449            1       True         47
# 44     RandomForest_r15_BAG_L1   0.942445     roc_auc       1.089839     6.272465                1.089839           6.272465            1       True         64
# 45     RandomForest_r39_BAG_L1   0.941020     roc_auc       1.118502     6.668958                1.118502           6.668958            1       True         35
# 46           LightGBMXT_BAG_L1   0.940674     roc_auc       0.577901    15.207410                0.577901          15.207410            1       True          1
# 47    RandomForest_r195_BAG_L1   0.939541     roc_auc       1.126619     6.596673                1.126619           6.596673            1       True         21
# 48     RandomForest_r16_BAG_L1   0.937910     roc_auc       1.088921     8.102414                1.088921           8.102414            1       True         73
# 49     RandomForestEntr_BAG_L1   0.937519     roc_auc       1.136971     2.495691                1.136971           2.495691            1       True          4
# 50        LightGBM_r196_BAG_L1   0.936658     roc_auc      18.564631   154.098169               18.564631         154.098169            1       True         34
# 51         LightGBM_r30_BAG_L1   0.936099     roc_auc       2.064792    42.027994                2.064792          42.027994            1       True         53
# 52    RandomForest_r166_BAG_L1   0.935752     roc_auc       1.153951     2.553467                1.153951           2.553467            1       True         60
# 53     RandomForestGini_BAG_L1   0.935752     roc_auc       1.169605     2.519707                1.169605           2.519707            1       True          3
# 54         LightGBM_r42_BAG_L1   0.935719     roc_auc       0.593919    16.674381                0.593919          16.674381            1       True         83
# 55        LightGBM_r188_BAG_L1   0.935538     roc_auc       0.613666    17.089859                0.613666          17.089859            1       True         22
# 56   NeuralNetTorch_r79_BAG_L1   0.931874     roc_auc       0.273890   406.215539                0.273890         406.215539            1       True         12
# 57  NeuralNetTorch_r135_BAG_L1   0.931794     roc_auc       0.320601   477.669174                0.320601         477.669174            1       True         75
# 58  NeuralNetTorch_r143_BAG_L1   0.931772     roc_auc       0.369890   807.656791                0.369890         807.656791            1       True         49
# 59  NeuralNetTorch_r185_BAG_L1   0.931690     roc_auc       1.210272   692.169392                1.210272         692.169392            1       True         62
# 60    NeuralNetTorch_r1_BAG_L1   0.931426     roc_auc       0.305633   445.391243                0.305633         445.391243            1       True         84
# 61       NeuralNetTorch_BAG_L1   0.931345     roc_auc       0.231653   231.157254                0.231653         231.157254            1       True          9
# 62   NeuralNetTorch_r22_BAG_L1   0.930992     roc_auc       0.289302   359.568127                0.289302         359.568127            1       True         16
# 63   NeuralNetTorch_r14_BAG_L1   0.930992     roc_auc       0.171952   134.396149                0.171952         134.396149            1       True         31
# 64   NeuralNetTorch_r86_BAG_L1   0.930839     roc_auc       0.834095   590.465135                0.834095         590.465135            1       True         26
# 65   NeuralNetTorch_r19_BAG_L1   0.930758     roc_auc       0.179038   141.222775                0.179038         141.222775            1       True         80
# 66        ExtraTrees_r4_BAG_L1   0.930713     roc_auc       1.035843     1.165696                1.035843           1.165696            1       True         52
# 67   NeuralNetTorch_r41_BAG_L1   0.930703     roc_auc       0.213669   312.312644                0.213669         312.312644            1       True         37
# 68      ExtraTrees_r172_BAG_L1   0.930637     roc_auc       1.147339     1.495455                1.147339           1.495455            1       True         29
# 69   NeuralNetTorch_r76_BAG_L1   0.930459     roc_auc       0.284389   231.483376                0.284389         231.483376            1       True         70
# 70   NeuralNetTorch_r71_BAG_L1   0.930438     roc_auc       0.164281    91.658154                0.164281          91.658154            1       True         57
# 71   NeuralNetTorch_r89_BAG_L1   0.930115     roc_auc       0.282880   379.227690                0.282880         379.227690            1       True         85
# 72   NeuralNetTorch_r36_BAG_L1   0.930087     roc_auc       0.205435   285.043768                0.205435         285.043768            1       True         77
# 73   NeuralNetTorch_r30_BAG_L1   0.930048     roc_auc       0.338150   532.221318                0.338150         532.221318            1       True         24
# 74      ExtraTrees_r178_BAG_L1   0.929491     roc_auc       1.153141     1.416693                1.153141           1.416693            1       True         59
# 75  NeuralNetTorch_r197_BAG_L1   0.929482     roc_auc       0.171775   109.944751                0.171775         109.944751            1       True         42
# 76   NeuralNetTorch_r87_BAG_L1   0.929154     roc_auc       0.225963   304.978228                0.225963         304.978228            1       True         56
# 77   NeuralNetTorch_r31_BAG_L1   0.928751     roc_auc       0.221914   281.605058                0.221914         281.605058            1       True         51
# 78  NeuralNetTorch_r121_BAG_L1   0.927484     roc_auc       1.695652  1092.157573                1.695652        1092.157573            1       True         72
# 79       ExtraTrees_r42_BAG_L1   0.925911     roc_auc       1.195783     1.530432                1.195783           1.530432            1       True         18
# 80      ExtraTrees_r197_BAG_L1   0.925512     roc_auc       1.162307     1.745696                1.162307           1.745696            1       True         71
# 81      ExtraTrees_r126_BAG_L1   0.925196     roc_auc       1.207258     1.122154                1.207258           1.122154            1       True         76
# 82       ExtraTreesEntr_BAG_L1   0.923262     roc_auc       1.290637     1.086006                1.290637           1.086006            1       True          7
# 83       ExtraTrees_r49_BAG_L1   0.922765     roc_auc       1.289564     1.292322                1.289564           1.292322            1       True         44
# 84       ExtraTreesGini_BAG_L1   0.922765     roc_auc       1.305286     1.153807                1.305286           1.153807            1       True          6
# 85  NeuralNetTorch_r158_BAG_L1   0.918308     roc_auc       0.737043   619.363109                0.737043         619.363109            1       True         40
# Number of models trained: 86
# Types of models trained:
# {'WeightedEnsembleModel', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 3 | ['person_home_ownership', 'loan_intent', 'loan_grade']
# ('float', [])     : 3 | ['person_emp_length', 'loan_int_rate', 'loan_percent_income']
# ('int', [])       : 5 | ['id', 'person_age', 'person_income', 'loan_amnt', 'cb_person_cred_hist_length']
# ('int', ['bool']) : 1 | ['cb_person_default_on_file']
# *** End of fit() summary ***
# C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %%
results
# Out:
# {'model_types': {'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r197_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r49_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r49_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r143_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r127_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForest_r34_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r94_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r143_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r128_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r31_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r4_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r30_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r49_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r5_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r87_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r71_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r143_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r178_BAG_L1': 'StackerEnsembleModel_XT',
#   'RandomForest_r166_BAG_L1': 'StackerEnsembleModel_RF',
#   'XGBoost_r31_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r185_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r60_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r15_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r135_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r22_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r6_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r121_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r180_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r76_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r197_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r121_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'RandomForest_r16_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r12_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r135_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r126_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r36_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r163_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_r198_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r19_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r95_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'XGBoost_r34_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r42_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r1_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r89_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'LightGBMXT_BAG_L1': 0.940673620846586,
#   'LightGBM_BAG_L1': 0.9569251261866367,
#   'RandomForestGini_BAG_L1': 0.9357520652104679,
#   'RandomForestEntr_BAG_L1': 0.9375187614630566,
#   'CatBoost_BAG_L1': 0.9557722253078096,
#   'ExtraTreesGini_BAG_L1': 0.9227649657440264,
#   'ExtraTreesEntr_BAG_L1': 0.9232617651663569,
#   'XGBoost_BAG_L1': 0.9555810835829088,
#   'NeuralNetTorch_BAG_L1': 0.931344521217035,
#   'LightGBMLarge_BAG_L1': 0.95583197339291,
#   'CatBoost_r177_BAG_L1': 0.9568443572145896,
#   'NeuralNetTorch_r79_BAG_L1': 0.931874453300378,
#   'LightGBM_r131_BAG_L1': 0.9585107577865444,
#   'CatBoost_r9_BAG_L1': 0.956352326066626,
#   'LightGBM_r96_BAG_L1': 0.9432095058317602,
#   'NeuralNetTorch_r22_BAG_L1': 0.9309918308328169,
#   'XGBoost_r33_BAG_L1': 0.9549864363131774,
#   'ExtraTrees_r42_BAG_L1': 0.9259111446061054,
#   'CatBoost_r137_BAG_L1': 0.9582315714529784,
#   'CatBoost_r13_BAG_L1': 0.9546149383309135,
#   'RandomForest_r195_BAG_L1': 0.93954090982961,
#   'LightGBM_r188_BAG_L1': 0.9355380524367312,
#   'XGBoost_r89_BAG_L1': 0.9568934888945639,
#   'NeuralNetTorch_r30_BAG_L1': 0.9300484328092994,
#   'LightGBM_r130_BAG_L1': 0.9584099334882278,
#   'NeuralNetTorch_r86_BAG_L1': 0.9308391531878087,
#   'CatBoost_r50_BAG_L1': 0.9582221218166114,
#   'XGBoost_r194_BAG_L1': 0.9557323408655399,
#   'ExtraTrees_r172_BAG_L1': 0.9306368045299201,
#   'CatBoost_r69_BAG_L1': 0.9572920856765443,
#   'NeuralNetTorch_r14_BAG_L1': 0.930991603431967,
#   'LightGBM_r161_BAG_L1': 0.9570513062750133,
#   'CatBoost_r70_BAG_L1': 0.9570273565603656,
#   'LightGBM_r196_BAG_L1': 0.936658052817717,
#   'RandomForest_r39_BAG_L1': 0.9410196499336548,
#   'CatBoost_r167_BAG_L1': 0.9543431800282525,
#   'NeuralNetTorch_r41_BAG_L1': 0.9307025209943965,
#   'XGBoost_r98_BAG_L1': 0.9565551819117506,
#   'LightGBM_r15_BAG_L1': 0.9583479947352537,
#   'NeuralNetTorch_r158_BAG_L1': 0.9183077221637845,
#   'CatBoost_r86_BAG_L1': 0.9528362660304206,
#   'NeuralNetTorch_r197_BAG_L1': 0.929481841565899,
#   'CatBoost_r49_BAG_L1': 0.9584314020333924,
#   'ExtraTrees_r49_BAG_L1': 0.9227649657440264,
#   'LightGBM_r143_BAG_L1': 0.9547757238282161,
#   'RandomForest_r127_BAG_L1': 0.9426919295914584,
#   'RandomForest_r34_BAG_L1': 0.9425657399784386,
#   'LightGBM_r94_BAG_L1': 0.9430338237929153,
#   'NeuralNetTorch_r143_BAG_L1': 0.9317720633888799,
#   'CatBoost_r128_BAG_L1': 0.9556576200417536,
#   'NeuralNetTorch_r31_BAG_L1': 0.9287513609821813,
#   'ExtraTrees_r4_BAG_L1': 0.9307131338277814,
#   'LightGBM_r30_BAG_L1': 0.9360994527497346,
#   'XGBoost_r49_BAG_L1': 0.956014582228326,
#   'CatBoost_r5_BAG_L1': 0.9584178960897174,
#   'NeuralNetTorch_r87_BAG_L1': 0.9291539021569148,
#   'NeuralNetTorch_r71_BAG_L1': 0.9304384693184462,
#   'CatBoost_r143_BAG_L1': 0.955421818456734,
#   'ExtraTrees_r178_BAG_L1': 0.9294909792702097,
#   'RandomForest_r166_BAG_L1': 0.9357520652104679,
#   'XGBoost_r31_BAG_L1': 0.9571983810488179,
#   'NeuralNetTorch_r185_BAG_L1': 0.931690260993075,
#   'CatBoost_r60_BAG_L1': 0.9574121747557672,
#   'RandomForest_r15_BAG_L1': 0.9424445805674663,
#   'LightGBM_r135_BAG_L1': 0.9552922071157417,
#   'XGBoost_r22_BAG_L1': 0.9566470137565609,
#   'CatBoost_r6_BAG_L1': 0.9580730171032823,
#   'LightGBM_r121_BAG_L1': 0.9573440473660494,
#   'CatBoost_r180_BAG_L1': 0.9585949103879923,
#   'NeuralNetTorch_r76_BAG_L1': 0.930458723471637,
#   'ExtraTrees_r197_BAG_L1': 0.9255119287223346,
#   'NeuralNetTorch_r121_BAG_L1': 0.9274835440958226,
#   'RandomForest_r16_BAG_L1': 0.9379096063762722,
#   'CatBoost_r12_BAG_L1': 0.9561574363947322,
#   'NeuralNetTorch_r135_BAG_L1': 0.9317939355407884,
#   'ExtraTrees_r126_BAG_L1': 0.9251960356054962,
#   'NeuralNetTorch_r36_BAG_L1': 0.9300871433393278,
#   'CatBoost_r163_BAG_L1': 0.9553547090132292,
#   'CatBoost_r198_BAG_L1': 0.9560399665923148,
#   'NeuralNetTorch_r19_BAG_L1': 0.9307578806002669,
#   'XGBoost_r95_BAG_L1': 0.956198669764557,
#   'XGBoost_r34_BAG_L1': 0.9556327023852682,
#   'LightGBM_r42_BAG_L1': 0.9357189087378478,
#   'NeuralNetTorch_r1_BAG_L1': 0.9314263974288226,
#   'NeuralNetTorch_r89_BAG_L1': 0.9301149672024873,
#   'WeightedEnsemble_L2': 0.9606779855142088},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'LightGBM_r196_BAG_L1': ['LightGBM_r196_BAG_L1'],
#   'RandomForest_r39_BAG_L1': ['RandomForest_r39_BAG_L1'],
#   'CatBoost_r167_BAG_L1': ['CatBoost_r167_BAG_L1'],
#   'NeuralNetTorch_r41_BAG_L1': ['NeuralNetTorch_r41_BAG_L1'],
#   'XGBoost_r98_BAG_L1': ['XGBoost_r98_BAG_L1'],
#   'LightGBM_r15_BAG_L1': ['LightGBM_r15_BAG_L1'],
#   'NeuralNetTorch_r158_BAG_L1': ['NeuralNetTorch_r158_BAG_L1'],
#   'CatBoost_r86_BAG_L1': ['CatBoost_r86_BAG_L1'],
#   'NeuralNetTorch_r197_BAG_L1': ['NeuralNetTorch_r197_BAG_L1'],
#   'CatBoost_r49_BAG_L1': ['CatBoost_r49_BAG_L1'],
#   'ExtraTrees_r49_BAG_L1': ['ExtraTrees_r49_BAG_L1'],
#   'LightGBM_r143_BAG_L1': ['LightGBM_r143_BAG_L1'],
#   'RandomForest_r127_BAG_L1': ['RandomForest_r127_BAG_L1'],
#   'RandomForest_r34_BAG_L1': ['RandomForest_r34_BAG_L1'],
#   'LightGBM_r94_BAG_L1': ['LightGBM_r94_BAG_L1'],
#   'NeuralNetTorch_r143_BAG_L1': ['NeuralNetTorch_r143_BAG_L1'],
#   'CatBoost_r128_BAG_L1': ['CatBoost_r128_BAG_L1'],
#   'NeuralNetTorch_r31_BAG_L1': ['NeuralNetTorch_r31_BAG_L1'],
#   'ExtraTrees_r4_BAG_L1': ['ExtraTrees_r4_BAG_L1'],
#   'LightGBM_r30_BAG_L1': ['LightGBM_r30_BAG_L1'],
#   'XGBoost_r49_BAG_L1': ['XGBoost_r49_BAG_L1'],
#   'CatBoost_r5_BAG_L1': ['CatBoost_r5_BAG_L1'],
#   'NeuralNetTorch_r87_BAG_L1': ['NeuralNetTorch_r87_BAG_L1'],
#   'NeuralNetTorch_r71_BAG_L1': ['NeuralNetTorch_r71_BAG_L1'],
#   'CatBoost_r143_BAG_L1': ['CatBoost_r143_BAG_L1'],
#   'ExtraTrees_r178_BAG_L1': ['ExtraTrees_r178_BAG_L1'],
#   'RandomForest_r166_BAG_L1': ['RandomForest_r166_BAG_L1'],
#   'XGBoost_r31_BAG_L1': ['XGBoost_r31_BAG_L1'],
#   'NeuralNetTorch_r185_BAG_L1': ['NeuralNetTorch_r185_BAG_L1'],
#   'CatBoost_r60_BAG_L1': ['CatBoost_r60_BAG_L1'],
#   'RandomForest_r15_BAG_L1': ['RandomForest_r15_BAG_L1'],
#   'LightGBM_r135_BAG_L1': ['LightGBM_r135_BAG_L1'],
#   'XGBoost_r22_BAG_L1': ['XGBoost_r22_BAG_L1'],
#   'CatBoost_r6_BAG_L1': ['CatBoost_r6_BAG_L1'],
#   'LightGBM_r121_BAG_L1': ['LightGBM_r121_BAG_L1'],
#   'CatBoost_r180_BAG_L1': ['CatBoost_r180_BAG_L1'],
#   'NeuralNetTorch_r76_BAG_L1': ['NeuralNetTorch_r76_BAG_L1'],
#   'ExtraTrees_r197_BAG_L1': ['ExtraTrees_r197_BAG_L1'],
#   'NeuralNetTorch_r121_BAG_L1': ['NeuralNetTorch_r121_BAG_L1'],
#   'RandomForest_r16_BAG_L1': ['RandomForest_r16_BAG_L1'],
#   'CatBoost_r12_BAG_L1': ['CatBoost_r12_BAG_L1'],
#   'NeuralNetTorch_r135_BAG_L1': ['NeuralNetTorch_r135_BAG_L1'],
#   'ExtraTrees_r126_BAG_L1': ['ExtraTrees_r126_BAG_L1'],
#   'NeuralNetTorch_r36_BAG_L1': ['NeuralNetTorch_r36_BAG_L1'],
#   'CatBoost_r163_BAG_L1': ['CatBoost_r163_BAG_L1'],
#   'CatBoost_r198_BAG_L1': ['CatBoost_r198_BAG_L1'],
#   'NeuralNetTorch_r19_BAG_L1': ['NeuralNetTorch_r19_BAG_L1'],
#   'XGBoost_r95_BAG_L1': ['XGBoost_r95_BAG_L1'],
#   'XGBoost_r34_BAG_L1': ['XGBoost_r34_BAG_L1'],
#   'LightGBM_r42_BAG_L1': ['LightGBM_r42_BAG_L1'],
#   'NeuralNetTorch_r1_BAG_L1': ['NeuralNetTorch_r1_BAG_L1'],
#   'NeuralNetTorch_r89_BAG_L1': ['NeuralNetTorch_r89_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'LightGBMXT_BAG_L1': 15.207409620285034,
#   'LightGBM_BAG_L1': 8.73481297492981,
#   'RandomForestGini_BAG_L1': 2.519707441329956,
#   'RandomForestEntr_BAG_L1': 2.4956908226013184,
#   'CatBoost_BAG_L1': 276.2484858036041,
#   'ExtraTreesGini_BAG_L1': 1.1538069248199463,
#   'ExtraTreesEntr_BAG_L1': 1.0860061645507812,
#   'XGBoost_BAG_L1': 11.910913705825806,
#   'NeuralNetTorch_BAG_L1': 231.15725374221802,
#   'LightGBMLarge_BAG_L1': 10.142675876617432,
#   'CatBoost_r177_BAG_L1': 43.1856050491333,
#   'NeuralNetTorch_r79_BAG_L1': 406.21553921699524,
#   'LightGBM_r131_BAG_L1': 18.48523449897766,
#   'CatBoost_r9_BAG_L1': 141.78888082504272,
#   'LightGBM_r96_BAG_L1': 61.425801515579224,
#   'NeuralNetTorch_r22_BAG_L1': 359.56812715530396,
#   'XGBoost_r33_BAG_L1': 26.25540018081665,
#   'ExtraTrees_r42_BAG_L1': 1.5304324626922607,
#   'CatBoost_r137_BAG_L1': 540.1324064731598,
#   'CatBoost_r13_BAG_L1': 144.76870775222778,
#   'RandomForest_r195_BAG_L1': 6.596672534942627,
#   'LightGBM_r188_BAG_L1': 17.089859008789062,
#   'XGBoost_r89_BAG_L1': 17.6149320602417,
#   'NeuralNetTorch_r30_BAG_L1': 532.2213184833527,
#   'LightGBM_r130_BAG_L1': 9.267841100692749,
#   'NeuralNetTorch_r86_BAG_L1': 590.4651348590851,
#   'CatBoost_r50_BAG_L1': 121.26519846916199,
#   'XGBoost_r194_BAG_L1': 8.071323156356812,
#   'ExtraTrees_r172_BAG_L1': 1.4954547882080078,
#   'CatBoost_r69_BAG_L1': 344.62370920181274,
#   'NeuralNetTorch_r14_BAG_L1': 134.39614868164062,
#   'LightGBM_r161_BAG_L1': 30.018357276916504,
#   'CatBoost_r70_BAG_L1': 125.75540947914124,
#   'LightGBM_r196_BAG_L1': 154.0981686115265,
#   'RandomForest_r39_BAG_L1': 6.668958425521851,
#   'CatBoost_r167_BAG_L1': 131.40992212295532,
#   'NeuralNetTorch_r41_BAG_L1': 312.3126435279846,
#   'XGBoost_r98_BAG_L1': 40.69144010543823,
#   'LightGBM_r15_BAG_L1': 20.627771377563477,
#   'NeuralNetTorch_r158_BAG_L1': 619.3631088733673,
#   'CatBoost_r86_BAG_L1': 271.2761743068695,
#   'NeuralNetTorch_r197_BAG_L1': 109.94475054740906,
#   'CatBoost_r49_BAG_L1': 83.04228353500366,
#   'ExtraTrees_r49_BAG_L1': 1.2923219203948975,
#   'LightGBM_r143_BAG_L1': 18.314972162246704,
#   'RandomForest_r127_BAG_L1': 7.800737380981445,
#   'RandomForest_r34_BAG_L1': 4.596449375152588,
#   'LightGBM_r94_BAG_L1': 46.81234073638916,
#   'NeuralNetTorch_r143_BAG_L1': 807.6567912101746,
#   'CatBoost_r128_BAG_L1': 115.23674607276917,
#   'NeuralNetTorch_r31_BAG_L1': 281.6050579547882,
#   'ExtraTrees_r4_BAG_L1': 1.165696382522583,
#   'LightGBM_r30_BAG_L1': 42.02799391746521,
#   'XGBoost_r49_BAG_L1': 21.585103511810303,
#   'CatBoost_r5_BAG_L1': 100.82865047454834,
#   'NeuralNetTorch_r87_BAG_L1': 304.97822761535645,
#   'NeuralNetTorch_r71_BAG_L1': 91.65815448760986,
#   'CatBoost_r143_BAG_L1': 36.94599175453186,
#   'ExtraTrees_r178_BAG_L1': 1.4166934490203857,
#   'RandomForest_r166_BAG_L1': 2.553467273712158,
#   'XGBoost_r31_BAG_L1': 149.8829300403595,
#   'NeuralNetTorch_r185_BAG_L1': 692.1693923473358,
#   'CatBoost_r60_BAG_L1': 356.9961323738098,
#   'RandomForest_r15_BAG_L1': 6.272465467453003,
#   'LightGBM_r135_BAG_L1': 12.488497495651245,
#   'XGBoost_r22_BAG_L1': 15.434594869613647,
#   'CatBoost_r6_BAG_L1': 92.09619474411011,
#   'LightGBM_r121_BAG_L1': 29.46340560913086,
#   'CatBoost_r180_BAG_L1': 38.69301104545593,
#   'NeuralNetTorch_r76_BAG_L1': 231.48337578773499,
#   'ExtraTrees_r197_BAG_L1': 1.7456960678100586,
#   'NeuralNetTorch_r121_BAG_L1': 1092.1575725078583,
#   'RandomForest_r16_BAG_L1': 8.102413892745972,
#   'CatBoost_r12_BAG_L1': 91.43237805366516,
#   'NeuralNetTorch_r135_BAG_L1': 477.66917419433594,
#   'ExtraTrees_r126_BAG_L1': 1.1221542358398438,
#   'NeuralNetTorch_r36_BAG_L1': 285.04376792907715,
#   'CatBoost_r163_BAG_L1': 130.6438684463501,
#   'CatBoost_r198_BAG_L1': 319.4835593700409,
#   'NeuralNetTorch_r19_BAG_L1': 141.2227747440338,
#   'XGBoost_r95_BAG_L1': 19.374841451644897,
#   'XGBoost_r34_BAG_L1': 20.30590796470642,
#   'LightGBM_r42_BAG_L1': 16.674381494522095,
#   'NeuralNetTorch_r1_BAG_L1': 445.39124274253845,
#   'NeuralNetTorch_r89_BAG_L1': 379.2276895046234,
#   'WeightedEnsemble_L2': 3.133025884628296},
#  'model_pred_times': {'LightGBMXT_BAG_L1': 0.5779006481170654,
#   'LightGBM_BAG_L1': 0.14525818824768066,
#   'RandomForestGini_BAG_L1': 1.1696045398712158,
#   'RandomForestEntr_BAG_L1': 1.1369712352752686,
#   'CatBoost_BAG_L1': 0.04599881172180176,
#   'ExtraTreesGini_BAG_L1': 1.305285930633545,
#   'ExtraTreesEntr_BAG_L1': 1.2906372547149658,
#   'XGBoost_BAG_L1': 0.15819859504699707,
#   'NeuralNetTorch_BAG_L1': 0.23165321350097656,
#   'LightGBMLarge_BAG_L1': 0.16299724578857422,
#   'CatBoost_r177_BAG_L1': 0.03667140007019043,
#   'NeuralNetTorch_r79_BAG_L1': 0.27388978004455566,
#   'LightGBM_r131_BAG_L1': 0.8331964015960693,
#   'CatBoost_r9_BAG_L1': 0.09399795532226562,
#   'LightGBM_r96_BAG_L1': 5.403109788894653,
#   'NeuralNetTorch_r22_BAG_L1': 0.28930163383483887,
#   'XGBoost_r33_BAG_L1': 0.5764951705932617,
#   'ExtraTrees_r42_BAG_L1': 1.1957828998565674,
#   'CatBoost_r137_BAG_L1': 0.0639963150024414,
#   'CatBoost_r13_BAG_L1': 0.05307126045227051,
#   'RandomForest_r195_BAG_L1': 1.1266193389892578,
#   'LightGBM_r188_BAG_L1': 0.6136658191680908,
#   'XGBoost_r89_BAG_L1': 0.19100046157836914,
#   'NeuralNetTorch_r30_BAG_L1': 0.3381502628326416,
#   'LightGBM_r130_BAG_L1': 0.17799639701843262,
#   'NeuralNetTorch_r86_BAG_L1': 0.834094762802124,
#   'CatBoost_r50_BAG_L1': 0.09599995613098145,
#   'XGBoost_r194_BAG_L1': 0.1001594066619873,
#   'ExtraTrees_r172_BAG_L1': 1.147338628768921,
#   'CatBoost_r69_BAG_L1': 0.05785846710205078,
#   'NeuralNetTorch_r14_BAG_L1': 0.1719517707824707,
#   'LightGBM_r161_BAG_L1': 0.8320255279541016,
#   'CatBoost_r70_BAG_L1': 0.10700178146362305,
#   'LightGBM_r196_BAG_L1': 18.56463074684143,
#   'RandomForest_r39_BAG_L1': 1.118502140045166,
#   'CatBoost_r167_BAG_L1': 0.043062686920166016,
#   'NeuralNetTorch_r41_BAG_L1': 0.2136690616607666,
#   'XGBoost_r98_BAG_L1': 1.0263051986694336,
#   'LightGBM_r15_BAG_L1': 0.864682674407959,
#   'NeuralNetTorch_r158_BAG_L1': 0.7370433807373047,
#   'CatBoost_r86_BAG_L1': 0.04804563522338867,
#   'NeuralNetTorch_r197_BAG_L1': 0.17177534103393555,
#   'CatBoost_r49_BAG_L1': 0.04360485076904297,
#   'ExtraTrees_r49_BAG_L1': 1.2895638942718506,
#   'LightGBM_r143_BAG_L1': 0.45799851417541504,
#   'RandomForest_r127_BAG_L1': 1.0608067512512207,
#   'RandomForest_r34_BAG_L1': 0.9709920883178711,
#   'LightGBM_r94_BAG_L1': 3.217877149581909,
#   'NeuralNetTorch_r143_BAG_L1': 0.3698902130126953,
#   'CatBoost_r128_BAG_L1': 0.0834646224975586,
#   'NeuralNetTorch_r31_BAG_L1': 0.22191381454467773,
#   'ExtraTrees_r4_BAG_L1': 1.0358431339263916,
#   'LightGBM_r30_BAG_L1': 2.0647921562194824,
#   'XGBoost_r49_BAG_L1': 0.30300307273864746,
#   'CatBoost_r5_BAG_L1': 0.042998552322387695,
#   'NeuralNetTorch_r87_BAG_L1': 0.22596335411071777,
#   'NeuralNetTorch_r71_BAG_L1': 0.16428089141845703,
#   'CatBoost_r143_BAG_L1': 0.04000520706176758,
#   'ExtraTrees_r178_BAG_L1': 1.1531405448913574,
#   'RandomForest_r166_BAG_L1': 1.1539511680603027,
#   'XGBoost_r31_BAG_L1': 1.7443864345550537,
#   'NeuralNetTorch_r185_BAG_L1': 1.2102720737457275,
#   'CatBoost_r60_BAG_L1': 0.05893969535827637,
#   'RandomForest_r15_BAG_L1': 1.089838981628418,
#   'LightGBM_r135_BAG_L1': 0.2180018424987793,
#   'XGBoost_r22_BAG_L1': 0.1969311237335205,
#   'CatBoost_r6_BAG_L1': 0.08358120918273926,
#   'LightGBM_r121_BAG_L1': 0.8126471042633057,
#   'CatBoost_r180_BAG_L1': 0.0681462287902832,
#   'NeuralNetTorch_r76_BAG_L1': 0.28438854217529297,
#   'ExtraTrees_r197_BAG_L1': 1.162306785583496,
#   'NeuralNetTorch_r121_BAG_L1': 1.6956515312194824,
#   'RandomForest_r16_BAG_L1': 1.0889208316802979,
#   'CatBoost_r12_BAG_L1': 0.04799485206604004,
#   'NeuralNetTorch_r135_BAG_L1': 0.3206007480621338,
#   'ExtraTrees_r126_BAG_L1': 1.2072579860687256,
#   'NeuralNetTorch_r36_BAG_L1': 0.20543503761291504,
#   'CatBoost_r163_BAG_L1': 0.03799629211425781,
#   'CatBoost_r198_BAG_L1': 0.0500028133392334,
#   'NeuralNetTorch_r19_BAG_L1': 0.17903757095336914,
#   'XGBoost_r95_BAG_L1': 0.2220017910003662,
#   'XGBoost_r34_BAG_L1': 0.3965318202972412,
#   'LightGBM_r42_BAG_L1': 0.5939192771911621,
#   'NeuralNetTorch_r1_BAG_L1': 0.3056333065032959,
#   'NeuralNetTorch_r89_BAG_L1': 0.2828795909881592,
#   'WeightedEnsemble_L2': 0.004998683929443359},
#  'num_bag_folds': 8,
#  'max_stack_level': 2,
#  'num_classes': 2,
#  'model_hyperparams': {'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r12_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r36_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r163_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r198_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r19_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r95_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r1_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                          model  score_val eval_metric  pred_time_val  \
#  0          WeightedEnsemble_L2   0.960678     roc_auc       1.451754
#  1         CatBoost_r180_BAG_L1   0.958595     roc_auc       0.068146
#  2         LightGBM_r131_BAG_L1   0.958511     roc_auc       0.833196
#  3          CatBoost_r49_BAG_L1   0.958431     roc_auc       0.043605
#  4           CatBoost_r5_BAG_L1   0.958418     roc_auc       0.042999
#  ..                         ...        ...         ...            ...
#  81      ExtraTrees_r126_BAG_L1   0.925196     roc_auc       1.207258
#  82       ExtraTreesEntr_BAG_L1   0.923262     roc_auc       1.290637
#  83       ExtraTrees_r49_BAG_L1   0.922765     roc_auc       1.289564
#  84       ExtraTreesGini_BAG_L1   0.922765     roc_auc       1.305286
#  85  NeuralNetTorch_r158_BAG_L1   0.918308     roc_auc       0.737043
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0   309.250093                0.004999           3.133026            2
#  1    38.693011                0.068146          38.693011            1
#  2    18.485234                0.833196          18.485234            1
#  3    83.042284                0.043605          83.042284            1
#  4   100.828650                0.042999         100.828650            1
#  ..         ...                     ...                ...          ...
#  81    1.122154                1.207258           1.122154            1
#  82    1.086006                1.290637           1.086006            1
#  83    1.292322                1.289564           1.292322            1
#  84    1.153807                1.305286           1.153807            1
#  85  619.363109                0.737043         619.363109            1
#
#      can_infer  fit_order
#  0        True         86
#  1        True         69
#  2        True         13
#  3        True         43
#  4        True         55
#  ..        ...        ...
#  81       True         76
#  82       True          7
#  83       True         44
#  84       True          6
#  85       True         40
#
#  [86 rows x 10 columns]}

# %%
# Get the leaderboard to see the performance of the models
leaderboard = predictor.leaderboard(silent=True)

# Print the leaderboard for reference
leaderboard
# Out:
#                          model  score_val eval_metric  pred_time_val  \
# 0          WeightedEnsemble_L2   0.960678     roc_auc       1.451754
# 1         CatBoost_r180_BAG_L1   0.958595     roc_auc       0.068146
# 2         LightGBM_r131_BAG_L1   0.958511     roc_auc       0.833196
# 3          CatBoost_r49_BAG_L1   0.958431     roc_auc       0.043605
# 4           CatBoost_r5_BAG_L1   0.958418     roc_auc       0.042999
# ..                         ...        ...         ...            ...
# 81      ExtraTrees_r126_BAG_L1   0.925196     roc_auc       1.207258
# 82       ExtraTreesEntr_BAG_L1   0.923262     roc_auc       1.290637
# 83       ExtraTrees_r49_BAG_L1   0.922765     roc_auc       1.289564
# 84       ExtraTreesGini_BAG_L1   0.922765     roc_auc       1.305286
# 85  NeuralNetTorch_r158_BAG_L1   0.918308     roc_auc       0.737043
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   309.250093                0.004999           3.133026            2
# 1    38.693011                0.068146          38.693011            1
# 2    18.485234                0.833196          18.485234            1
# 3    83.042284                0.043605          83.042284            1
# 4   100.828650                0.042999         100.828650            1
# ..         ...                     ...                ...          ...
# 81    1.122154                1.207258           1.122154            1
# 82    1.086006                1.290637           1.086006            1
# 83    1.292322                1.289564           1.292322            1
# 84    1.153807                1.305286           1.153807            1
# 85  619.363109                0.737043         619.363109            1
#
#     can_infer  fit_order
# 0        True         86
# 1        True         69
# 2        True         13
# 3        True         43
# 4        True         55
# ..        ...        ...
# 81       True         76
# 82       True          7
# 83       True         44
# 84       True          6
# 85       True         40
#
# [86 rows x 10 columns]

# %%
# Get the top 10 models based on the leaderboard
top_10_models = leaderboard['model'].head(10).tolist()
top_10_models
# Out:
# ['WeightedEnsemble_L2',
#  'CatBoost_r180_BAG_L1',
#  'LightGBM_r131_BAG_L1',
#  'CatBoost_r49_BAG_L1',
#  'CatBoost_r5_BAG_L1',
#  'LightGBM_r130_BAG_L1',
#  'LightGBM_r15_BAG_L1',
#  'CatBoost_r137_BAG_L1',
#  'CatBoost_r50_BAG_L1',
#  'CatBoost_r6_BAG_L1']

# %%
# Iterate through the top 10 models and print their hyperparameters
for model in top_10_models:
    hyperparameters = predictor.info()['model_info'][model]['hyperparameters']
    print(f"Model: {model}")
    print("Hyperparameters:")
    print(hyperparameters)
    print("-" * 50)
# Out:
# Model: WeightedEnsemble_L2
# Hyperparameters:
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r180_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: LightGBM_r131_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r49_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r5_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: LightGBM_r130_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: LightGBM_r15_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r137_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r50_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r6_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------

# %%
# Get details of the best model
best_model = predictor.get_model_best()
print(f"Best Model: {best_model}")

# Get model hyperparameters and other info
best_model_info = predictor.info()
print(best_model_info)
# Out:
# Best Model: WeightedEnsemble_L2
# C:\Users\Hi\AppData\Local\Temp\ipykernel_16288\3617745900.py:2: DeprecationWarning: `get_model_best` has been deprecated and will be removed in version 1.2. Please use `model_best` instead. This will raise an error in the future!
#   best_model = predictor.get_model_best()
# {'path': 'AutogluonModels\\ag-20241004_153801', 'label': 'loan_status', 'random_state': 0, 'version': '1.1.1', 'features': ['id', 'person_age', 'person_income', 'person_home_ownership', 'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_default_on_file', 'cb_person_cred_hist_length'], 'feature_metadata_in': <autogluon.common.features.feature_metadata.FeatureMetadata object at 0x00000194401F0130>, 'time_fit_preprocessing': 0.18399715423583984, 'time_fit_training': 13124.051141262054, 'time_fit_total': 13124.23513841629, 'time_limit': 29653.10773730278, 'time_train_start': 1728066228.6048856, 'num_rows_train': 58645, 'num_cols_train': 12, 'num_rows_val': None, 'num_classes': 2, 'problem_type': 'binary', 'eval_metric': 'roc_auc', 'best_model': 'WeightedEnsemble_L2', 'best_model_score_val': 0.9606779855142088, 'best_model_stack_level': 2, 'num_models_trained': 86, 'num_bag_folds': 8, 'max_stack_level': 2, 'max_core_stack_level': 1, 'model_info': {'LightGBMXT_BAG_L1': {'name': 'LightGBMXT_BAG_L1', 'model_type': 'StackerEnsembleModel', 'problem_type': 'binary', 'eval_metric': 'roc_auc', 'stopping_metric': 'log_loss', 'fit_time': 15.207409620285034, 'num_classes': 2, 'quantile_levels': None, 'predict_time': 0.5779006481170654, 'val_score': 0.940673620846586, 'hyperparameters': {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}, 'hyperparameters_fit': {}, 'hyperparameters_nondefault': [], 'ag_args_fit': {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}, 'num_features': 12, 'features': ['person_emp_length', 'loan_int_rate', 'person_income', 'person_home_ownership', 'loan_amnt', 'loan_percent_income', 'cb_person_cred_hist_length', 'id', 'loan_intent', 'loan_grade', 'person_age', 'cb_person_default_on_file'], 'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata object at 0x000001963ABF6D90>, 'memory_size': 3167, 'compile_time': None, 'is_initialized': True, 'is_fit': True, 'is_valid': True, 'can_infer': True, 'bagged_info': {'child_model_type': 'LGBModel', 'num_child_models': 8, 'child_model_names': ['S1F1', 'S1F2', 'S1F3', 'S1F4', 'S1F5', 'S1F6', 'S1F7', 'S1F8'], '_n_repeats': 1, '_k_per_n_repeat': [8], '_random_state': 1, 'low_memory': True, 'bagged_mode': True, 'max_memory_size': 28911107, 'min_memory_size': 4298081, 'child_hyperparameters': {'learning_rate': 0.05, 'extra_trees': True}, 'child_hyperparameters_fit': {'num_boost_round': 1069}, 'child_ag_args_fit': {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'num_cpus': 10, 'num_gpus': 0, 'memory_ratio': 0.8}}, 'stacker_info': {'num_base_models': 0, 'base_model_names': []}, 'children_info': {'S1F1': {'name': 'S1F1', 'model_type': 'LGBModel', 'problem_type': 'binary', 'eval_metric': 'roc_auc', 'stopping_metric': 'log_loss', 'fit_time': 2.1306357383728027, 'num_classes': 2, 'quantile_levels': None, 'predict_time': 0.07499957084655762, 'val_score': 0.9415463521089251, 'hyperparameters': {'learning_rate': 0.05, 'extra_trees': True}, 'hyperparameters_fit': {'num_boost_round': 922}, 'hyperparameters_nondefault': ['extra_trees'], 'ag_args_fit': {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'],  ...

# %%
# Feature importance
feature_importance = predictor.feature_importance(train_df)
print("Feature Importance:\n", feature_importance)
# Out:
# Computing feature importance via permutation shuffling for 12 features using 5000 rows with 5 shuffle sets...
# 	82.75s	= Expected runtime (16.55s per shuffle set)
# 	44.39s	= Actual runtime (Completed 5 of 5 shuffle sets)
# Feature Importance:
#                              importance    stddev       p_value  n  p99_high  \
# person_income                 0.068442  0.004535  2.300236e-06  5  0.077780
# loan_percent_income           0.058402  0.003636  1.794551e-06  5  0.065890
# person_home_ownership         0.046422  0.001913  3.453345e-07  5  0.050362
# loan_intent                   0.026337  0.002155  5.330892e-06  5  0.030774
# loan_int_rate                 0.021572  0.002339  1.632511e-05  5  0.026388
# loan_grade                    0.018485  0.001523  5.481144e-06  5  0.021621
# loan_amnt                     0.007756  0.000727  9.137966e-06  5  0.009252
# person_emp_length             0.007399  0.000261  1.862172e-07  5  0.007937
# id                            0.007263  0.000692  9.763873e-06  5  0.008688
# person_age                    0.007139  0.000743  1.390443e-05  5  0.008670
# cb_person_cred_hist_length    0.002612  0.000583  2.798541e-04  5  0.003813
# cb_person_default_on_file     0.000350  0.000071  1.953993e-04  5  0.000496
#
#                              p99_low
# person_income               0.059104
# loan_percent_income         0.050914
# person_home_ownership       0.042483
# loan_intent                 0.021900
# loan_int_rate               0.016756
# loan_grade                  0.015349
# loan_amnt                   0.006260
# person_emp_length           0.006861
# id                          0.005838
# person_age                  0.005608
# cb_person_cred_hist_length  0.001411
# cb_person_default_on_file   0.000203

# %%
sample_submission_df = pd.read_csv("sample_submission.csv")
sample_submission_df.head()
# Out:
#       id  loan_status
# 0  58645          0.5
# 1  58646          0.5
# 2  58647          0.5
# 3  58648          0.5
# 4  58649          0.5

# %%
# Make predictions on the test data
y_pred_predictor = predictor.predict(test_df)

# Create the submission file
sample_submission_df['loan_status'] = y_pred_predictor
sample_submission_df.head()
# Out:
#       id  loan_status
# 0  58645            1
# 1  58646            0
# 2  58647            1
# 3  58648            0
# 4  58649            0

# %%
sample_submission_df.to_csv('25_01 - Submission.csv', index=False)
