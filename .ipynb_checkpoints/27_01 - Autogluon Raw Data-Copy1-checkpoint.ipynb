# %%
import pandas as pd
import tensorflow as tf

from autogluon.tabular import TabularPredictor

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
gpus = len(tf.config.list_physical_devices('GPU'))
cpus = len(tf.config.list_physical_devices('CPU'))

print(gpus, cpus)
# Out:
# 1 1

# %%
train_df.head(2)
# Out:
#    id      Name  Gender   Age      City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0  Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0  Varanasi            Working Professional
#
#   Profession  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0       Chef                NaN            5.0   NaN                 NaN
# 1    Teacher                NaN            4.0   NaN                 NaN
#
#    Job Satisfaction     Sleep Duration Dietary Habits Degree  \
# 0               2.0  More than 8 hours        Healthy    BHM
# 1               3.0  Less than 5 hours      Unhealthy    LLB
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No               1.0               2.0
# 1                                   Yes               7.0               3.0
#
#   Family History of Mental Illness  Depression
# 0                               No           0
# 1                               No           1

# %%
test_df.head(2)
# Out:
#        id    Name  Gender   Age           City  \
# 0  140700  Shivam    Male  53.0  Visakhapatnam
# 1  140701   Sanya  Female  58.0        Kolkata
#
#   Working Professional or Student              Profession  Academic Pressure  \
# 0            Working Professional                   Judge                NaN
# 1            Working Professional  Educational Consultant                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            2.0   NaN                 NaN               5.0
# 1            2.0   NaN                 NaN               4.0
#
#       Sleep Duration Dietary Habits Degree  \
# 0  Less than 5 hours       Moderate    LLB
# 1  Less than 5 hours       Moderate   B.Ed
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No               9.0               3.0
# 1                                    No               6.0               4.0
#
#   Family History of Mental Illness
# 0                              Yes
# 1                               No

# %%
train_df['Depression'].nunique()
# Out:
# 2

# %%
# Train the AutoGluon TabularPredictor
# Set up the TabularPredictor with GPU and memory optimization
predictor = TabularPredictor(
    label='Depression',
    eval_metric='roc_auc',
    problem_type='binary'
).fit(
    train_df,
    presets='best_quality',
    time_limit=3600 * 11,
    verbosity=2,
    excluded_model_types=['KNN'],
    ag_args_fit={'num_cpus': 10, 'num_gpus': 0, 'memory_ratio': 0.8}
)

# Summarize results
results = predictor.fit_summary()
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20241102_072842"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.8.19
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          20
# Memory Avail:       21.36 GB / 31.82 GB (67.1%)
# Disk Space Avail:   660.56 GB / 953.00 GB (69.3%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 9900s of the 39600s of remaining time (25%).
# 		Context path: "AutogluonModels\ag-20241102_072842\ds_sub_fit\sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                         model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         CatBoost_r13_BAG_L2       0.976512   0.976148     roc_auc       24.639758      42.108495  6813.235703                 0.151080                0.097082         306.736595            2       True         59
# 1         CatBoost_r50_BAG_L2       0.976467   0.976071     roc_auc       24.611097      42.087526  6542.121390                 0.122419                0.076113          35.622282            2       True         66
# 2          CatBoost_r9_BAG_L2       0.976464   0.976101     roc_auc       24.648836      42.111405  6603.158556                 0.160158                0.099992          96.659447            2       True         53
# 3         WeightedEnsemble_L3       0.976456   0.976219     roc_auc       27.418504      44.468014  7436.645564                 0.008000                0.012017           7.058413            3       True         71
# 4             CatBoost_BAG_L2       0.976446   0.976097     roc_auc       24.611679      42.091418  6591.965120                 0.123001                0.080005          85.466012            2       True         44
# 5        CatBoost_r177_BAG_L2       0.976414   0.975979     roc_auc       24.604400      42.084415  6570.626348                 0.115722                0.073003          64.127239            2       True         50
# 6        CatBoost_r137_BAG_L2       0.976413   0.976022     roc_auc       24.614674      42.087415  6599.649875                 0.125996                0.076002          93.150767            2       True         58
# 7         CatBoost_r69_BAG_L2       0.976381   0.976065     roc_auc       24.598817      42.082417  6571.733352                 0.110139                0.071004          65.234244            2       True         69
# 8   NeuralNetTorch_r30_BAG_L2       0.976374   0.974626     roc_auc       25.864847      43.326697  6903.383843                 1.376169                1.315285         396.884735            2       True         63
# 9   NeuralNetTorch_r79_BAG_L2       0.976360   0.974853     roc_auc       25.693604      43.190803  6786.451874                 1.204926                1.179391         279.952766            2       True         51
# 10        WeightedEnsemble_L2       0.976351   0.976239     roc_auc        9.426732      10.977927  2792.429861                 0.010000                0.014046           7.048719            2       True         39
# 11         XGBoost_r89_BAG_L2       0.976297   0.976005     roc_auc       25.155679      42.485412  6541.631290                 0.667001                0.473999          35.132182            2       True         62
# 12        CatBoost_r13_BAG_L1       0.976276   0.975844     roc_auc        0.400808       0.306027   935.249902                 0.400808                0.306027         935.249902            1       True         20
# 13        LightGBM_r96_BAG_L2       0.976252   0.975847     roc_auc       24.779343      42.313415  6520.412277                 0.290665                0.302002          13.913168            2       True         54
# 14       CatBoost_r167_BAG_L1       0.976224   0.975711     roc_auc        0.173277       0.101959   163.098763                 0.173277                0.101959         163.098763            1       True         36
# 15  NeuralNetTorch_r22_BAG_L2       0.976207   0.974926     roc_auc       25.727620      43.211602  6807.752057                 1.238942                1.200190         301.252949            2       True         55
# 16             XGBoost_BAG_L2       0.976179   0.975820     roc_auc       25.120587      42.467423  6537.458677                 0.631909                0.456011          30.959569            2       True         47
# 17        CatBoost_r69_BAG_L1       0.976135   0.975898     roc_auc        0.271000       0.177999   405.326896                 0.271000                0.177999         405.326896            1       True         30
# 18       CatBoost_r177_BAG_L1       0.976134   0.975826     roc_auc        0.200004       0.126994   229.063262                 0.200004                0.126994         229.063262            1       True         11
# 19          LightGBMXT_BAG_L2       0.976131   0.975624     roc_auc       24.683417      42.148417  6516.014434                 0.194739                0.137005           9.515326            2       True         40
# 20            CatBoost_BAG_L1       0.976121   0.975845     roc_auc        0.517040       0.167322   350.922147                 0.517040                0.167322         350.922147            1       True          5
# 21  NeuralNetTorch_r86_BAG_L2       0.976104   0.974871     roc_auc       27.785990      44.996099  7203.161608                 3.297312                2.984687         696.662500            2       True         65
# 22  NeuralNetTorch_r14_BAG_L2       0.976080   0.974777     roc_auc       25.515484      42.965809  6533.582247                 1.026806                0.954396          27.083139            2       True         70
# 23         XGBoost_r33_BAG_L2       0.976062   0.975732     roc_auc       25.481677      42.831808  6618.201566                 0.992999                0.820395         111.702457            2       True         56
# 24       CatBoost_r137_BAG_L1       0.976049   0.975903     roc_auc        0.221961       0.128004   418.509421                 0.221961                0.128004         418.509421            1       True         19
# 25      NeuralNetTorch_BAG_L2       0.976048   0.975275     roc_auc       25.663576      43.113715  6695.577770                 1.174898                1.102303         189.078661            2       True         48
# 26       LightGBM_r188_BAG_L2       0.976032   0.975491     roc_auc       24.738678      42.220411  6518.975146                 0.250000                0.208998          12.476037            2       True         61
# 27       LightGBM_r131_BAG_L2       0.975970   0.975528     roc_auc       24.871782      42.378411  6524.783623                 0.383104                0.366998          18.284515            2       True         52
# 28       LightGBM_r130_BAG_L2       0.975949   0.975284     roc_auc       24.676678      42.167415  6517.050260                 0.188000                0.156003          10.551151            2       True         64
# 29       LightGBMLarge_BAG_L2       0.975939   0.975211     roc_auc       24.739192      42.205496  6520.922124                 0.250514                0.194083          14.423016            2       True         49
# 30         XGBoost_r89_BAG_L1       0.975851   0.975383     roc_auc        0.548372       0.395529    74.105038                 0.548372                0.395529          74.105038            1       True         23
# 31            LightGBM_BAG_L2       0.975807   0.975335     roc_auc       24.664758      42.148408  6516.174081                 0.176080                0.136996           9.674973            2       True         41
# 32       LightGBM_r196_BAG_L1       0.975739   0.975548     roc_auc        3.643711       5.177737    80.107066                 3.643711                5.177737          80.107066            1       True         34
# 33        LightGBM_r96_BAG_L1       0.975712   0.975557     roc_auc        0.957999       1.343001    22.875158                 0.957999                1.343001          22.875158            1       True         15
# 34             XGBoost_BAG_L1       0.975690   0.975004     roc_auc        0.708292       0.366996    54.914527                 0.708292                0.366996          54.914527            1       True          8
# 35        CatBoost_r70_BAG_L1       0.975659   0.975223     roc_auc        0.164994       0.121061   134.053547                 0.164994                0.121061         134.053547            1       True         33
# 36       LightGBM_r188_BAG_L1       0.975636   0.975190     roc_auc        0.381596       0.442999    13.590390                 0.381596                0.442999          13.590390            1       True         22
# 37        CatBoost_r50_BAG_L1       0.975602   0.975261     roc_auc        0.145001       0.099997   101.753793                 0.145001                0.099997         101.753793            1       True         27
# 38         CatBoost_r9_BAG_L1       0.975589   0.975057     roc_auc        0.184664       0.138249   162.704519                 0.184664                0.138249         162.704519            1       True         14
# 39         XGBoost_r33_BAG_L1       0.975498   0.974986     roc_auc        1.480999       1.482857   157.955485                 1.480999                1.482857         157.955485            1       True         17
# 40        XGBoost_r194_BAG_L2       0.975483   0.974572     roc_auc       24.806746      42.186415  6521.776158                 0.318068                0.175003          15.277050            2       True         67
# 41  NeuralNetTorch_r79_BAG_L1       0.975418   0.974421     roc_auc        0.541370       0.518245   285.810414                 0.541370                0.518245         285.810414            1       True         12
# 42       LightGBM_r161_BAG_L1       0.975392   0.974973     roc_auc        1.600371       1.964002    41.380530                 1.600371                1.964002          41.380530            1       True         32
# 43      ExtraTreesGini_BAG_L2       0.975340   0.974057     roc_auc       24.926529      45.433018  6511.704744                 0.437851                3.421606           5.205636            2       True         45
# 44     ExtraTrees_r172_BAG_L2       0.975316   0.974772     roc_auc       24.743601      45.176243  6527.581877                 0.254923                3.164830          21.082769            2       True         68
# 45  NeuralNetTorch_r41_BAG_L1       0.975316   0.974075     roc_auc        0.435963       0.389390   171.155537                 0.435963                0.389390         171.155537            1       True         37
# 46          LightGBMXT_BAG_L1       0.975312   0.974947     roc_auc        0.357958       0.301924     9.906424                 0.357958                0.301924           9.906424            1       True          1
# 47  NeuralNetTorch_r30_BAG_L1       0.975270   0.974332     roc_auc        0.686745       0.638719   385.637781                 0.686745                0.638719         385.637781            1       True         24
# 48  NeuralNetTorch_r22_BAG_L1       0.975264   0.974081     roc_auc        0.564927       0.553003   334.933326                 0.564927                0.553003         334.933326            1       True         16
# 49    RandomForestEntr_BAG_L2       0.975201   0.973831     roc_auc       24.781797      45.187928  6531.914836                 0.293119                3.176516          25.415728            2       True         43
# 50       LightGBM_r130_BAG_L1       0.975192   0.974571     roc_auc        0.275288       0.293001    10.915302                 0.275288                0.293001          10.915302            1       True         25
# 51  NeuralNetTorch_r14_BAG_L1       0.975144   0.974120     roc_auc        0.360919       0.308392   106.446534                 0.360919                0.308392         106.446534            1       True         31
# 52      NeuralNetTorch_BAG_L1       0.975135   0.973847     roc_auc        0.489467       0.441494   199.512810                 0.489467                0.441494         199.512810            1       True          9
# 53  NeuralNetTorch_r86_BAG_L1       0.975087   0.973974     roc_auc        2.960503       2.586408  1516.036049                 2.960503                2.586408        1516.036049            1       True         26
# 54       LightGBM_r131_BAG_L1       0.975033   0.974656     roc_auc        0.894612       1.360997    23.393374                 0.894612                1.360997          23.393374            1       True         13
# 55      ExtraTreesEntr_BAG_L2       0.974974   0.974107     roc_auc       24.926882      45.419950  6511.426779                 0.438204                3.408537           4.927670            2       True         46
# 56            LightGBM_BAG_L1       0.974707   0.973952     roc_auc        0.217999       0.221953     9.540062                 0.217999                0.221953           9.540062            1       True          2
# 57      ExtraTrees_r42_BAG_L2       0.974681   0.973485     roc_auc       24.857583      45.278290  6523.274093                 0.368905                3.266877          16.774985            2       True         57
# 58       LightGBMLarge_BAG_L1       0.974454   0.973738     roc_auc        0.343907       0.379423    13.599167                 0.343907                0.379423          13.599167            1       True         10
# 59        XGBoost_r194_BAG_L1       0.974173   0.973175     roc_auc        0.272907       0.135759    11.763065                 0.272907                0.135759          11.763065            1       True         28
# 60    RandomForestGini_BAG_L2       0.974163   0.973445     roc_auc       24.809682      45.283168  6533.710213                 0.321004                3.271756          27.211105            2       True         42
# 61   RandomForest_r195_BAG_L2       0.973831   0.972319     roc_auc       24.731152      45.308409  6702.421851                 0.242474                3.296997         195.922743            2       True         60
# 62         XGBoost_r98_BAG_L1       0.973664   0.973160     roc_auc        1.368008       0.745816    34.158542                 1.368008                0.745816          34.158542            1       True         38
# 63      ExtraTreesEntr_BAG_L1       0.973200   0.971639     roc_auc        0.520040       2.873839     2.826999                 0.520040                2.873839           2.826999            1       True          7
# 64      ExtraTreesGini_BAG_L1       0.973093   0.971562     roc_auc        0.508792       2.904107     2.829001                 0.508792                2.904107           2.829001            1       True          6
# 65    RandomForestEntr_BAG_L1       0.973035   0.971656     roc_auc        0.406647       2.572977     4.616030                 0.406647                2.572977           4.616030            1       True          4
# 66     ExtraTrees_r172_BAG_L1       0.972710   0.971734     roc_auc        0.285367       2.386939     5.513199                 0.285367                2.386939           5.513199            1       True         29
# 67    RandomForestGini_BAG_L1       0.972017   0.971160     roc_auc        0.391060       2.603405     4.983654                 0.391060                2.603405           4.983654            1       True          3
# 68      ExtraTrees_r42_BAG_L1       0.971658   0.970573     roc_auc        0.428041       2.484383     4.664926                 0.428041                2.484383           4.664926            1       True         18
# 69    RandomForest_r39_BAG_L1       0.970260   0.969612     roc_auc        0.272732       2.367424    11.200308                 0.272732                2.367424          11.200308            1       True         35
# 70   RandomForest_r195_BAG_L1       0.970222   0.968670     roc_auc        0.305337       2.403079    11.446161                 0.305337                2.403079          11.446161            1       True         21
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	9958s	 = DyStack   runtime |	29642s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 29642s
# AutoGluon will save models to "AutogluonModels\ag-20241102_072842"
# Train Data Rows:    140700
# Train Data Columns: 19
# Label Column:       Depression
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    22253.64 MB
# 	Train Data (Original)  Memory Usage: 95.11 MB (0.4% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  :  8 | ['Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', ...]
# 		('int', [])    :  1 | ['id']
# 		('object', []) : 10 | ['Name', 'Gender', 'City', 'Working Professional or Student', 'Profession', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 6 | ['Name', 'City', 'Profession', 'Sleep Duration', 'Dietary Habits', ...]
# 		('float', [])     : 8 | ['Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', ...]
# 		('int', [])       : 1 | ['id']
# 		('int', ['bool']) : 4 | ['Gender', 'Working Professional or Student', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']
# 	0.5s = Fit runtime
# 	19 features in original data used to generate 19 features in processed data.
# 	Train Data (Processed) Memory Usage: 11.14 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.58s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 108 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 19756.2s of the 29641.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.34%)
# 	0.975	 = Validation score   (roc_auc)
# 	10.17s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 19744.28s of the 29629.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.34%)
# 	0.9743	 = Validation score   (roc_auc)
# 	9.43s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 19733.12s of the 29618.62s of remaining time.
# 	0.9713	 = Validation score   (roc_auc)
# 	5.38s	 = Training   runtime
# 	3.52s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 19723.83s of the 29609.33s of remaining time.
# 	0.9719	 = Validation score   (roc_auc)
# 	5.13s	 = Training   runtime
# 	3.4s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 19714.94s of the 29600.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.36%)
# 	0.9759	 = Validation score   (roc_auc)
# 	403.86s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 19309.31s of the 29194.8s of remaining time.
# 	0.9719	 = Validation score   (roc_auc)
# 	3.39s	 = Training   runtime
# 	3.72s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 19301.71s of the 29187.21s of remaining time.
# 	0.9719	 = Validation score   (roc_auc)
# 	3.32s	 = Training   runtime
# 	3.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 19294.16s of the 29179.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.57%)
# 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=14120, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14120, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 19292.36s of the 29177.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.47%)
# 2024-11-02 14:22:29,835	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-11-02 14:22:29,837	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9751	 = Validation score   (roc_auc)
# 	57.88s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 19232.76s of the 29118.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.30%)
# 	0.9739	 = Validation score   (roc_auc)
# 	225.12s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 19005.82s of the 28891.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.39%)
# 	0.9739	 = Validation score   (roc_auc)
# 	14.74s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 18989.33s of the 28874.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.36%)
# 	0.9759	 = Validation score   (roc_auc)
# 	285.45s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 18702.12s of the 28587.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.30%)
# 	0.974	 = Validation score   (roc_auc)
# 	305.38s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 18395.02s of the 28280.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.35%)
# 	0.9748	 = Validation score   (roc_auc)
# 	23.29s	 = Training   runtime
# 	1.57s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 18369.87s of the 28255.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.54%)
# 	Warning: Exception caused NeuralNetFastAI_r191_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=24136, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=24136, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 18368.04s of the 28253.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.45%)
# 2024-11-02 14:37:54,552	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=19564, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=19564, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# 2024-11-02 14:37:54,554	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9752	 = Validation score   (roc_auc)
# 	173.33s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 18193.0s of the 28078.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.33%)
# 	0.9756	 = Validation score   (roc_auc)
# 	24.45s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 18166.65s of the 28052.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.30%)
# 	0.9742	 = Validation score   (roc_auc)
# 	372.3s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 17792.6s of the 27678.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.68%)
# 	0.9751	 = Validation score   (roc_auc)
# 	198.27s	 = Training   runtime
# 	1.57s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 17592.37s of the 27477.87s of remaining time.
# 	0.9704	 = Validation score   (roc_auc)
# 	5.96s	 = Training   runtime
# 	3.43s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 17582.61s of the 27468.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.33%)
# 	0.976	 = Validation score   (roc_auc)
# 	617.15s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 16963.72s of the 26849.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.55%)
# 	Warning: Exception caused NeuralNetFastAI_r102_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=8648, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=8648, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 16961.83s of the 26847.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.45%)
# 2024-11-02 15:01:20,606	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-11-02 15:01:20,608	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9759	 = Validation score   (roc_auc)
# 	1011.75s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 15948.23s of the 25833.72s of remaining time.
# 	0.969	 = Validation score   (roc_auc)
# 	13.16s	 = Training   runtime
# 	3.3s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 15931.43s of the 25816.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.39%)
# 	0.9753	 = Validation score   (roc_auc)
# 	14.2s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 15915.48s of the 25800.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.55%)
# 	Warning: Exception caused NeuralNetFastAI_r145_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=21212, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=21212, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 15913.66s of the 25799.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.46%)
# 2024-11-02 15:18:49,081	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-11-02 15:18:49,083	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=11460, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=11460, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# 	0.9755	 = Validation score   (roc_auc)
# 	87.84s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 15824.09s of the 25709.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.30%)
# 	0.9743	 = Validation score   (roc_auc)
# 	498.62s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 15323.71s of the 25209.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.37%)
# 	0.9748	 = Validation score   (roc_auc)
# 	11.81s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 15310.17s of the 25195.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.30%)
# 	0.9737	 = Validation score   (roc_auc)
# 	1624.41s	 = Training   runtime
# 	2.51s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 13683.72s of the 23569.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.33%)
# 	0.9753	 = Validation score   (roc_auc)
# 	110.74s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 13571.29s of the 23456.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.55%)
# 	Warning: Exception caused NeuralNetFastAI_r11_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=9448, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=9448, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 13569.49s of the 23454.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.48%)
# 2024-11-02 15:57:52,838	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-11-02 15:57:52,840	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9733	 = Validation score   (roc_auc)
# 	12.75s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 13555.05s of the 23440.55s of remaining time.
# 	0.9721	 = Validation score   (roc_auc)
# 	7.06s	 = Training   runtime
# 	3.31s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 13544.37s of the 23429.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.34%)
# 	0.976	 = Validation score   (roc_auc)
# 	474.33s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 13068.29s of the 22953.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.55%)
# 	Warning: Exception caused NeuralNetFastAI_r103_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=17668, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=17668, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 13066.49s of the 22951.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=0.30%)
# 2024-11-02 16:06:15,795	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-11-02 16:06:15,800	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9742	 = Validation score   (roc_auc)
# ...
# 38         LightGBM_r196_BAG_L1   0.975594     roc_auc       5.900009     87.456224                5.900009          87.456224            1       True         34
# 39           XGBoost_r31_BAG_L1   0.975582     roc_auc       2.593003   1052.116416                2.593003        1052.116416            1       True         61
# 40          LightGBM_r96_BAG_L1   0.975572     roc_auc       1.474181     24.449675                1.474181          24.449675            1       True         15
# 41         LightGBM_r131_BAG_L2   0.975546     roc_auc     113.846275  19575.506658                0.466425          26.055453            2       True         91
# 42          CatBoost_r49_BAG_L1   0.975543     roc_auc       0.056005    158.736592                0.056005         158.736592            1       True         43
# 43           XGBoost_r89_BAG_L1   0.975520     roc_auc       0.416000     87.838786                0.416000          87.838786            1       True         23
# 44      RandomForest_r34_BAG_L2   0.975514     roc_auc     118.432716  19878.292149                5.052866         328.840945            2       True        125
# 45         LightGBM_r130_BAG_L2   0.975438     roc_auc     113.578850  19563.158517                0.199000          13.707312            2       True        103
# 46           XGBoost_r22_BAG_L1   0.975427     roc_auc       0.461002     87.338560                0.461002          87.338560            1       True         66
# 47              LightGBM_BAG_L2   0.975381     roc_auc     113.564887  19562.529379                0.185037          13.078175            2       True         80
# 48           XGBoost_r98_BAG_L2   0.975351     roc_auc     114.645764  19766.801121                1.265914         217.349917            2       True        116
# 49    NeuralNetTorch_r22_BAG_L2   0.975312     roc_auc     115.504159  19914.767758                2.124309         365.316554            2       True         94
# 50           XGBoost_r49_BAG_L1   0.975307     roc_auc       0.697001    138.214197                0.697001         138.214197            1       True         54
# 51          CatBoost_r70_BAG_L1   0.975291     roc_auc       0.135044    138.591285                0.135044         138.591285            1       True         33
# 52        NeuralNetTorch_BAG_L2   0.975283     roc_auc     115.380861  19765.373389                2.001011         215.922185            2       True         87
# 53          CatBoost_r50_BAG_L1   0.975282     roc_auc       0.118011    110.735278                0.118011         110.735278            1       True         27
# 54         LightGBM_r188_BAG_L1   0.975274     roc_auc       0.499996     14.196529                0.499996          14.196529            1       True         22
# 55           CatBoost_r6_BAG_L1   0.975261     roc_auc       0.103987     92.766968                0.103987          92.766968            1       True         67
# 56    NeuralNetTorch_r86_BAG_L2   0.975243     roc_auc     117.185194  21072.330097                3.805345        1522.878892            2       True        104
# 57           CatBoost_r9_BAG_L1   0.975216     roc_auc       0.146041    173.333805                0.146041         173.333805            1       True         14
# 58         LightGBM_r143_BAG_L2   0.975215     roc_auc     113.906851  19593.110640                0.527001          43.659436            2       True        123
# 59          LightGBM_r30_BAG_L1   0.975205     roc_auc       1.722503     30.846461                1.722503          30.846461            1       True         53
# 60         LightGBMLarge_BAG_L2   0.975195     roc_auc     113.636106  19571.409420                0.256256          21.958215            2       True         88
# 61         CatBoost_r128_BAG_L1   0.975148     roc_auc       0.147037    149.923410                0.147037         149.923410            1       True         50
# 62         CatBoost_r180_BAG_L1   0.975131     roc_auc       0.103445     93.009471                0.103445          93.009471            1       True         69
# 63    NeuralNetTorch_r41_BAG_L2   0.975122     roc_auc     115.362485  19782.315135                1.982635         232.863930            2       True        115
# 64           XGBoost_r33_BAG_L1   0.975095     roc_auc       1.574996    198.272085                1.574996         198.272085            1       True         17
# 65         LightGBM_r161_BAG_L1   0.975094     roc_auc       2.133799     44.866190                2.133799          44.866190            1       True         32
# 66               XGBoost_BAG_L1   0.975082     roc_auc       0.369630     57.878672                0.369630          57.878672            1       True          8
# 67         LightGBM_r121_BAG_L1   0.975067     roc_auc       2.082999     43.349022                2.082999          43.349022            1       True         68
# 68    NeuralNetTorch_r14_BAG_L2   0.975027     roc_auc     115.279987  19695.311507                1.900137         145.860303            2       True        109
# 69            LightGBMXT_BAG_L1   0.975015     roc_auc       0.337995     10.166859                0.337995          10.166859            1       True          1
# 70   NeuralNetTorch_r197_BAG_L2   0.974981     roc_auc     115.259344  19725.510775                1.879494         176.059570            2       True        120
# 71    NeuralNetTorch_r30_BAG_L2   0.974980     roc_auc     115.635121  19996.841421                2.255271         447.390217            2       True        102
# 72           XGBoost_r98_BAG_L1   0.974954     roc_auc       2.432995    121.111213                2.432995         121.111213            1       True         38
# 73          LightGBM_r15_BAG_L1   0.974936     roc_auc       0.921879     16.329261                0.921879          16.329261            1       True         39
# 74    NeuralNetTorch_r87_BAG_L1   0.974811     roc_auc       0.459298    266.764831                0.459298         266.764831            1       True         56
# 75         LightGBM_r130_BAG_L1   0.974794     roc_auc       0.326993     11.810745                0.326993          11.810745            1       True         25
# 76         LightGBM_r131_BAG_L1   0.974768     roc_auc       1.571996     23.291437                1.571996          23.291437            1       True         13
# 77    NeuralNetTorch_r76_BAG_L1   0.974760     roc_auc       0.935491    450.213573                0.935491         450.213573            1       True         70
# 78       ExtraTrees_r172_BAG_L2   0.974724     roc_auc     118.675835  19604.574541                5.295985          55.123336            2       True        107
# 79          XGBoost_r194_BAG_L2   0.974697     roc_auc     113.654855  19574.204571                0.275005          24.753366            2       True        106
# 80    NeuralNetTorch_r31_BAG_L1   0.974683     roc_auc       0.458601    370.757877                0.458601         370.757877            1       True         51
# 81   NeuralNetTorch_r135_BAG_L1   0.974519     roc_auc       0.688579    174.457263                0.688579         174.457263            1       True         75
# 82   NeuralNetTorch_r143_BAG_L1   0.974503     roc_auc       0.796003    675.586376                0.796003         675.586376            1       True         49
# 83        ExtraTreesGini_BAG_L2   0.974386     roc_auc     118.975386  19558.249205                5.595536           8.798000            2       True         84
# 84        ExtraTrees_r49_BAG_L2   0.974386     roc_auc     118.989099  19558.290534                5.609249           8.839329            2       True        122
# 85    NeuralNetTorch_r30_BAG_L1   0.974291     roc_auc       0.718542    498.618984                0.718542         498.618984            1       True         24
# 86              LightGBM_BAG_L1   0.974287     roc_auc       0.278994      9.434935                0.278994           9.434935            1       True          2
# 87    NeuralNetTorch_r22_BAG_L1   0.974240     roc_auc       0.611085    372.302882                0.611085         372.302882            1       True         16
# 88        ExtraTreesEntr_BAG_L2   0.974208     roc_auc     118.965282  19557.797017                5.585432           8.345813            2       True         85
# 89      RandomForestEntr_BAG_L2   0.974173     roc_auc     118.715159  19593.139246                5.335309          43.688042            2       True         82
# 90    NeuralNetTorch_r14_BAG_L1   0.974156     roc_auc       0.341904    117.448421                0.341904         117.448421            1       True         31
# 91    NeuralNetTorch_r41_BAG_L1   0.974011     roc_auc       0.419449    220.573608                0.419449         220.573608            1       True         37
# 92    NeuralNetTorch_r36_BAG_L1   0.973996     roc_auc       0.401893     28.048687                0.401893          28.048687            1       True         77
# 93    NeuralNetTorch_r79_BAG_L1   0.973985     roc_auc       0.565737    305.384621                0.565737         305.384621            1       True         12
# 94         LightGBM_r135_BAG_L1   0.973971     roc_auc       0.387998     16.069726                0.387998          16.069726            1       True         65
# 95     RandomForest_r127_BAG_L2   0.973950     roc_auc     118.717103  20168.766497                5.337253         619.315292            2       True        124
# 96        NeuralNetTorch_BAG_L1   0.973934     roc_auc       0.489151    225.123746                0.489151         225.123746            1       True          9
# 97   NeuralNetTorch_r121_BAG_L1   0.973920     roc_auc       6.842994   2881.972811                6.842994        2881.972811            1       True         72
# 98         LightGBMLarge_BAG_L1   0.973874     roc_auc       0.432997     14.743253                0.432997          14.743253            1       True         10
# 99         LightGBM_r143_BAG_L1   0.973747     roc_auc       1.187994     26.631285                1.187994          26.631285            1       True         45
# 100   NeuralNetTorch_r86_BAG_L1   0.973731     roc_auc       2.505122   1624.409044                2.505122        1624.409044            1       True         26
# 101  NeuralNetTorch_r185_BAG_L1   0.973644     roc_auc       0.582245    849.941180                0.582245         849.941180            1       True         62
# 102       ExtraTrees_r42_BAG_L2   0.973611     roc_auc     118.778492  19594.037374                5.398643          44.586169            2       True         96
# 103         XGBoost_r194_BAG_L1   0.973327     roc_auc       0.144003     12.745865                0.144003          12.745865            1       True         28
# 104   NeuralNetTorch_r71_BAG_L1   0.973321     roc_auc       0.335531    106.439444                0.335531         106.439444            1       True         57
# 105     RandomForest_r39_BAG_L2   0.973000     roc_auc     118.838112  20060.238264                5.458262         510.787059            2       True        113
# 106     RandomForestGini_BAG_L2   0.972984     roc_auc     118.848925  19598.912221                5.469075          49.461017            2       True         81
# 107  NeuralNetTorch_r197_BAG_L1   0.972911     roc_auc       0.359210    117.707414                0.359210         117.707414            1       True         42
# 108        ExtraTrees_r4_BAG_L1   0.972639     roc_auc       3.163526      6.640264                3.163526           6.640264            1       True         52
# 109      ExtraTrees_r178_BAG_L1   0.972423     roc_auc       3.320223      5.784873                3.320223           5.784873            1       True         59
# 110      ExtraTrees_r126_BAG_L1   0.972384     roc_auc       3.575509      3.423002                3.575509           3.423002            1       True         76
# 111    RandomForest_r195_BAG_L2   0.972295     roc_auc     118.891665  20094.037137                5.511815         544.585933            2       True         99
# 112      ExtraTrees_r172_BAG_L1   0.972116     roc_auc       3.313251      7.062151                3.313251           7.062151            1       True         29
# 113     RandomForest_r34_BAG_L1   0.972080     roc_auc       3.010002     10.594020                3.010002          10.594020            1       True         47
# 114       ExtraTreesGini_BAG_L1   0.971941     roc_auc       3.716956      3.392538                3.716956           3.392538            1       True          6
# 115       ExtraTrees_r49_BAG_L1   0.971903     roc_auc       3.688267      3.459505                3.688267           3.459505            1       True         44
# 116       ExtraTreesEntr_BAG_L1   0.971894     roc_auc       3.715605      3.316920                3.715605           3.316920            1       True          7
# 117     RandomForestEntr_BAG_L1   0.971893     roc_auc       3.401478      5.133316                3.401478           5.133316            1       True          4
# 118    RandomForest_r166_BAG_L1   0.971285     roc_auc       3.459348      5.391890                3.459348           5.391890            1       True         60
# 119     RandomForestGini_BAG_L1   0.971285     roc_auc       3.524363      5.376056                3.524363           5.376056            1       True          3
# 120  NeuralNetTorch_r158_BAG_L1   0.971081     roc_auc       3.429570   1887.901425                3.429570        1887.901425            1       True         40
# 121    RandomForest_r127_BAG_L1   0.970655     roc_auc       3.150795     16.312004                3.150795          16.312004            1       True         46
# 122      ExtraTrees_r197_BAG_L1   0.970506     roc_auc       3.398355      7.914002                3.398355           7.914002            1       True         71
# 123       ExtraTrees_r42_BAG_L1   0.970356     roc_auc       3.429574      5.957618                3.429574           5.957618            1       True         18
# 124     RandomForest_r15_BAG_L1   0.970274     roc_auc       3.227589     13.075002                3.227589          13.075002            1       True         64
# 125     RandomForest_r39_BAG_L1   0.969649     roc_auc       3.293276     12.923516                3.293276          12.923516            1       True         35
# 126    RandomForest_r195_BAG_L1   0.968985     roc_auc       3.299845     13.162429                3.299845          13.162429            1       True         21
# 127     RandomForest_r16_BAG_L1   0.968302     roc_auc       3.301172     17.510628                3.301172          17.510628            1       True         73
# 128  NeuralNetTorch_r158_BAG_L2   0.963984     roc_auc     118.948769  21384.344268                5.568919        1834.893063            2       True        118
# Number of models trained: 129
# Types of models trained:
# {'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_XT', 'WeightedEnsembleModel', 'StackerEnsembleModel_CatBoost'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 6 | ['Name', 'City', 'Profession', 'Sleep Duration', 'Dietary Habits', ...]
# ('float', [])     : 8 | ['Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', ...]
# ('int', [])       : 1 | ['id']
# ('int', ['bool']) : 4 | ['Gender', 'Working Professional or Student', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness']
# *** End of fit() summary ***
# C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %%
results
# Out:
# {'model_types': {'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'XGBoost_r194_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r14_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r70_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r196_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r41_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r86_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r197_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r49_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r49_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r143_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForest_r127_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForest_r34_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r94_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r143_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r128_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r31_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r4_BAG_L1': 'StackerEnsembleModel_XT',
#   'LightGBM_r30_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r49_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r5_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r87_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'NeuralNetTorch_r71_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r143_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r178_BAG_L1': 'StackerEnsembleModel_XT',
#   'RandomForest_r166_BAG_L1': 'StackerEnsembleModel_RF',
#   'XGBoost_r31_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r185_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r60_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r15_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r135_BAG_L1': 'StackerEnsembleModel_LGB',
#   'XGBoost_r22_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'CatBoost_r6_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r121_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r180_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r76_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r197_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r121_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'RandomForest_r16_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_r12_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r135_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'ExtraTrees_r126_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetTorch_r36_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r9_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L2': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_r13_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L2': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L2': 'StackerEnsembleModel_LGB',
#   'XGBoost_r89_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_r30_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r130_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r86_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r50_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'XGBoost_r194_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r172_BAG_L2': 'StackerEnsembleModel_XT',
#   'CatBoost_r69_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r14_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r161_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r70_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r196_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForest_r39_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_r167_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r41_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r98_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'LightGBM_r15_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r158_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r86_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r197_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r49_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTrees_r49_BAG_L2': 'StackerEnsembleModel_XT',
#   'LightGBM_r143_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForest_r127_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForest_r34_BAG_L2': 'StackerEnsembleModel_RF',
#   'LightGBM_r94_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r143_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'CatBoost_r128_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'LightGBMXT_BAG_L1': 0.9750151855526674,
#   'LightGBM_BAG_L1': 0.9742872058472379,
#   'RandomForestGini_BAG_L1': 0.9712846911531922,
#   'RandomForestEntr_BAG_L1': 0.9718931052406601,
#   'CatBoost_BAG_L1': 0.9759395315909754,
#   'ExtraTreesGini_BAG_L1': 0.9719410600376832,
#   'ExtraTreesEntr_BAG_L1': 0.9718936778377867,
#   'XGBoost_BAG_L1': 0.9750823344983993,
#   'NeuralNetTorch_BAG_L1': 0.9739342731830573,
#   'LightGBMLarge_BAG_L1': 0.9738740599495387,
#   'CatBoost_r177_BAG_L1': 0.9758844000507919,
#   'NeuralNetTorch_r79_BAG_L1': 0.9739854045267617,
#   'LightGBM_r131_BAG_L1': 0.9747683330033123,
#   'CatBoost_r9_BAG_L1': 0.9752158345587443,
#   'LightGBM_r96_BAG_L1': 0.9755722374570673,
#   'NeuralNetTorch_r22_BAG_L1': 0.9742395189189983,
#   'XGBoost_r33_BAG_L1': 0.9750946044853565,
#   'ExtraTrees_r42_BAG_L1': 0.9703555154933774,
#   'CatBoost_r137_BAG_L1': 0.975996868589803,
#   'CatBoost_r13_BAG_L1': 0.9759371550835896,
#   'RandomForest_r195_BAG_L1': 0.9689846585215426,
#   'LightGBM_r188_BAG_L1': 0.975273726149568,
#   'XGBoost_r89_BAG_L1': 0.9755196877846749,
#   'NeuralNetTorch_r30_BAG_L1': 0.9742910064585418,
#   'LightGBM_r130_BAG_L1': 0.9747936760739974,
#   'NeuralNetTorch_r86_BAG_L1': 0.9737310946259842,
#   'CatBoost_r50_BAG_L1': 0.9752815278066493,
#   'XGBoost_r194_BAG_L1': 0.9733267007505172,
#   'ExtraTrees_r172_BAG_L1': 0.9721163479679444,
#   'CatBoost_r69_BAG_L1': 0.9759950003027087,
#   'NeuralNetTorch_r14_BAG_L1': 0.9741562762740825,
#   'LightGBM_r161_BAG_L1': 0.9750943556408621,
#   'CatBoost_r70_BAG_L1': 0.9752909507747878,
#   'LightGBM_r196_BAG_L1': 0.9755938521068305,
#   'RandomForest_r39_BAG_L1': 0.9696491949409588,
#   'CatBoost_r167_BAG_L1': 0.9758640748061868,
#   'NeuralNetTorch_r41_BAG_L1': 0.9740114514961392,
#   'XGBoost_r98_BAG_L1': 0.9749539202080234,
#   'LightGBM_r15_BAG_L1': 0.9749360473981001,
#   'NeuralNetTorch_r158_BAG_L1': 0.9710806763767018,
#   'CatBoost_r86_BAG_L1': 0.9758983059567423,
#   'NeuralNetTorch_r197_BAG_L1': 0.972910728896605,
#   'CatBoost_r49_BAG_L1': 0.9755429361452549,
#   'ExtraTrees_r49_BAG_L1': 0.971902661718541,
#   'LightGBM_r143_BAG_L1': 0.973747151975187,
#   'RandomForest_r127_BAG_L1': 0.9706551483846284,
#   'RandomForest_r34_BAG_L1': 0.9720804542304193,
#   'LightGBM_r94_BAG_L1': 0.9756658716102625,
#   'NeuralNetTorch_r143_BAG_L1': 0.9745033810511636,
#   'CatBoost_r128_BAG_L1': 0.9751482842344863,
#   'NeuralNetTorch_r31_BAG_L1': 0.974683170094227,
#   'ExtraTrees_r4_BAG_L1': 0.9726385560377677,
#   'LightGBM_r30_BAG_L1': 0.9752054970658564,
#   'XGBoost_r49_BAG_L1': 0.9753070161073978,
#   'CatBoost_r5_BAG_L1': 0.9759792181262571,
#   'NeuralNetTorch_r87_BAG_L1': 0.9748111689077201,
#   'NeuralNetTorch_r71_BAG_L1': 0.9733206668235739,
#   'CatBoost_r143_BAG_L1': 0.9758329334039941,
#   'ExtraTrees_r178_BAG_L1': 0.9724226768993394,
#   'RandomForest_r166_BAG_L1': 0.9712846911531922,
#   'XGBoost_r31_BAG_L1': 0.975582251537042,
#   'NeuralNetTorch_r185_BAG_L1': 0.9736443540597907,
#   'CatBoost_r60_BAG_L1': 0.9759646614877078,
#   'RandomForest_r15_BAG_L1': 0.9702742019453369,
#   'LightGBM_r135_BAG_L1': 0.9739707536160661,
#   'XGBoost_r22_BAG_L1': 0.9754265971825935,
#   'CatBoost_r6_BAG_L1': 0.9752613647780797,
#   'LightGBM_r121_BAG_L1': 0.975066892550973,
#   'CatBoost_r180_BAG_L1': 0.9751313770770889,
#   'NeuralNetTorch_r76_BAG_L1': 0.9747601726024955,
#   'ExtraTrees_r197_BAG_L1': 0.9705062766987828,
#   'NeuralNetTorch_r121_BAG_L1': 0.9739196934435858,
#   'RandomForest_r16_BAG_L1': 0.9683024726577388,
#   'CatBoost_r12_BAG_L1': 0.9759217798910343,
#   'NeuralNetTorch_r135_BAG_L1': 0.9745192670119059,
#   'ExtraTrees_r126_BAG_L1': 0.9723840414560239,
#   'NeuralNetTorch_r36_BAG_L1': 0.9739956847769228,
#   'WeightedEnsemble_L2': 0.9763045794999051,
#   'LightGBMXT_BAG_L2': 0.9757337074687149,
#   'LightGBM_BAG_L2': 0.9753808441073015,
#   'RandomForestGini_BAG_L2': 0.972984321810652,
#   'RandomForestEntr_BAG_L2': 0.9741728498269838,
#   'CatBoost_BAG_L2': 0.9761311542513672,
#   'ExtraTreesGini_BAG_L2': 0.974386306765761,
#   'ExtraTreesEntr_BAG_L2': 0.9742083102523552,
#   'XGBoost_BAG_L2': 0.9758752753563273,
#   'NeuralNetTorch_BAG_L2': 0.9752827268464346,
#   'LightGBMLarge_BAG_L2': 0.9751948439736036,
#   'CatBoost_r177_BAG_L2': 0.9761111940353068,
#   'NeuralNetTorch_r79_BAG_L2': 0.9757108214189242,
#   'LightGBM_r131_BAG_L2': 0.9755458453327324,
#   'CatBoost_r9_BAG_L2': 0.9761949544126585,
#   'LightGBM_r96_BAG_L2': 0.9760234725292126,
#   'NeuralNetTorch_r22_BAG_L2': 0.9753118002064987,
#   'XGBoost_r33_BAG_L2': 0.9757378143370996,
#   'ExtraTrees_r42_BAG_L2': 0.9736109998949858,
#   'CatBoost_r137_BAG_L2': 0.9761346647422642,
#   'CatBoost_r13_BAG_L2': 0.976252406916098,
#   'RandomForest_r195_BAG_L2': 0.9722948270528233,
#   'LightGBM_r188_BAG_L2': 0.9756698767326732,
#   'XGBoost_r89_BAG_L2': 0.9760395832143686,
#   'NeuralNetTorch_r30_BAG_L2': 0.9749800638275835,
#   'LightGBM_r130_BAG_L2': 0.9754379339602322,
#   'NeuralNetTorch_r86_BAG_L2': 0.9752425565506612,
#   'CatBoost_r50_BAG_L2': 0.9761185316356249,
#   'XGBoost_r194_BAG_L2': 0.9746973299404633,
#   'ExtraTrees_r172_BAG_L2': 0.9747243294831679,
#   'CatBoost_r69_BAG_L2': 0.9761576217934191,
#   'NeuralNetTorch_r14_BAG_L2': 0.9750274893417094,
#   'LightGBM_r161_BAG_L2': 0.9756013962565718,
#   'CatBoost_r70_BAG_L2': 0.976189799000203,
#   'LightGBM_r196_BAG_L2': 0.9759213443707044,
#   'RandomForest_r39_BAG_L2': 0.973000445914726,
#   'CatBoost_r167_BAG_L2': 0.9761058798040103,
#   'NeuralNetTorch_r41_BAG_L2': 0.9751218834473057,
#   'XGBoost_r98_BAG_L2': 0.9753507215237279,
#   'LightGBM_r15_BAG_L2': 0.9756607374302724,
#   'NeuralNetTorch_r158_BAG_L2': 0.9639840278510753,
#   'CatBoost_r86_BAG_L2': 0.9762146034457061,
#   'NeuralNetTorch_r197_BAG_L2': 0.9749805479277942,
#   'CatBoost_r49_BAG_L2': 0.976156594991393,
#   'ExtraTrees_r49_BAG_L2': 0.974386306765761,
#   'LightGBM_r143_BAG_L2': 0.9752150389358013,
#   'RandomForest_r127_BAG_L2': 0.9739496375045902,
#   'RandomForest_r34_BAG_L2': 0.9755138114875548,
#   'LightGBM_r94_BAG_L2': 0.9760050862333463,
#   'NeuralNetTorch_r143_BAG_L2': 0.9756245280933816,
#   'CatBoost_r128_BAG_L2': 0.9761137714867449,
#   'WeightedEnsemble_L3': 0.976302552903549},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'NeuralNetTorch_r30_BAG_L1': ['NeuralNetTorch_r30_BAG_L1'],
#   'LightGBM_r130_BAG_L1': ['LightGBM_r130_BAG_L1'],
#   'NeuralNetTorch_r86_BAG_L1': ['NeuralNetTorch_r86_BAG_L1'],
#   'CatBoost_r50_BAG_L1': ['CatBoost_r50_BAG_L1'],
#   'XGBoost_r194_BAG_L1': ['XGBoost_r194_BAG_L1'],
#   'ExtraTrees_r172_BAG_L1': ['ExtraTrees_r172_BAG_L1'],
#   'CatBoost_r69_BAG_L1': ['CatBoost_r69_BAG_L1'],
#   'NeuralNetTorch_r14_BAG_L1': ['NeuralNetTorch_r14_BAG_L1'],
#   'LightGBM_r161_BAG_L1': ['LightGBM_r161_BAG_L1'],
#   'CatBoost_r70_BAG_L1': ['CatBoost_r70_BAG_L1'],
#   'LightGBM_r196_BAG_L1': ['LightGBM_r196_BAG_L1'],
#   'RandomForest_r39_BAG_L1': ['RandomForest_r39_BAG_L1'],
#   'CatBoost_r167_BAG_L1': ['CatBoost_r167_BAG_L1'],
#   'NeuralNetTorch_r41_BAG_L1': ['NeuralNetTorch_r41_BAG_L1'],
#   'XGBoost_r98_BAG_L1': ['XGBoost_r98_BAG_L1'],
#   'LightGBM_r15_BAG_L1': ['LightGBM_r15_BAG_L1'],
#   'NeuralNetTorch_r158_BAG_L1': ['NeuralNetTorch_r158_BAG_L1'],
#   'CatBoost_r86_BAG_L1': ['CatBoost_r86_BAG_L1'],
#   'NeuralNetTorch_r197_BAG_L1': ['NeuralNetTorch_r197_BAG_L1'],
#   'CatBoost_r49_BAG_L1': ['CatBoost_r49_BAG_L1'],
#   'ExtraTrees_r49_BAG_L1': ['ExtraTrees_r49_BAG_L1'],
#   'LightGBM_r143_BAG_L1': ['LightGBM_r143_BAG_L1'],
#   'RandomForest_r127_BAG_L1': ['RandomForest_r127_BAG_L1'],
#   'RandomForest_r34_BAG_L1': ['RandomForest_r34_BAG_L1'],
#   'LightGBM_r94_BAG_L1': ['LightGBM_r94_BAG_L1'],
#   'NeuralNetTorch_r143_BAG_L1': ['NeuralNetTorch_r143_BAG_L1'],
#   'CatBoost_r128_BAG_L1': ['CatBoost_r128_BAG_L1'],
#   'NeuralNetTorch_r31_BAG_L1': ['NeuralNetTorch_r31_BAG_L1'],
#   'ExtraTrees_r4_BAG_L1': ['ExtraTrees_r4_BAG_L1'],
#   'LightGBM_r30_BAG_L1': ['LightGBM_r30_BAG_L1'],
#   'XGBoost_r49_BAG_L1': ['XGBoost_r49_BAG_L1'],
#   'CatBoost_r5_BAG_L1': ['CatBoost_r5_BAG_L1'],
#   'NeuralNetTorch_r87_BAG_L1': ['NeuralNetTorch_r87_BAG_L1'],
#   'NeuralNetTorch_r71_BAG_L1': ['NeuralNetTorch_r71_BAG_L1'],
#   'CatBoost_r143_BAG_L1': ['CatBoost_r143_BAG_L1'],
#   'ExtraTrees_r178_BAG_L1': ['ExtraTrees_r178_BAG_L1'],
#   'RandomForest_r166_BAG_L1': ['RandomForest_r166_BAG_L1'],
#   'XGBoost_r31_BAG_L1': ['XGBoost_r31_BAG_L1'],
#   'NeuralNetTorch_r185_BAG_L1': ['NeuralNetTorch_r185_BAG_L1'],
#   'CatBoost_r60_BAG_L1': ['CatBoost_r60_BAG_L1'],
#   'RandomForest_r15_BAG_L1': ['RandomForest_r15_BAG_L1'],
#   'LightGBM_r135_BAG_L1': ['LightGBM_r135_BAG_L1'],
#   'XGBoost_r22_BAG_L1': ['XGBoost_r22_BAG_L1'],
#   'CatBoost_r6_BAG_L1': ['CatBoost_r6_BAG_L1'],
#   'LightGBM_r121_BAG_L1': ['LightGBM_r121_BAG_L1'],
#   'CatBoost_r180_BAG_L1': ['CatBoost_r180_BAG_L1'],
#   'NeuralNetTorch_r76_BAG_L1': ['NeuralNetTorch_r76_BAG_L1'],
#   'ExtraTrees_r197_BAG_L1': ['ExtraTrees_r197_BAG_L1'],
#   'NeuralNetTorch_r121_BAG_L1': ['NeuralNetTorch_r121_BAG_L1'],
#   'RandomForest_r16_BAG_L1': ['RandomForest_r16_BAG_L1'],
#   'CatBoost_r12_BAG_L1': ['CatBoost_r12_BAG_L1'],
#   'NeuralNetTorch_r135_BAG_L1': ['NeuralNetTorch_r135_BAG_L1'],
#   'ExtraTrees_r126_BAG_L1': ['ExtraTrees_r126_BAG_L1'],
#   'NeuralNetTorch_r36_BAG_L1': ['NeuralNetTorch_r36_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'NeuralNetTorch_BAG_L2': ['NeuralNetTorch_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'CatBoost_r177_BAG_L2': ['CatBoost_r177_BAG_L2'],
#   'NeuralNetTorch_r79_BAG_L2': ['NeuralNetTorch_r79_BAG_L2'],
#   'LightGBM_r131_BAG_L2': ['LightGBM_r131_BAG_L2'],
#   'CatBoost_r9_BAG_L2': ['CatBoost_r9_BAG_L2'],
#   'LightGBM_r96_BAG_L2': ['LightGBM_r96_BAG_L2'],
#   'NeuralNetTorch_r22_BAG_L2': ['NeuralNetTorch_r22_BAG_L2'],
#   'XGBoost_r33_BAG_L2': ['XGBoost_r33_BAG_L2'],
#   'ExtraTrees_r42_BAG_L2': ['ExtraTrees_r42_BAG_L2'],
#   'CatBoost_r137_BAG_L2': ['CatBoost_r137_BAG_L2'],
#   'CatBoost_r13_BAG_L2': ['CatBoost_r13_BAG_L2'],
#   'RandomForest_r195_BAG_L2': ['RandomForest_r195_BAG_L2'],
#   'LightGBM_r188_BAG_L2': ['LightGBM_r188_BAG_L2'],
#   'XGBoost_r89_BAG_L2': ['XGBoost_r89_BAG_L2'],
#   'NeuralNetTorch_r30_BAG_L2': ['NeuralNetTorch_r30_BAG_L2'],
#   'LightGBM_r130_BAG_L2': ['LightGBM_r130_BAG_L2'],
#   'NeuralNetTorch_r86_BAG_L2': ['NeuralNetTorch_r86_BAG_L2'],
#   'CatBoost_r50_BAG_L2': ['CatBoost_r50_BAG_L2'],
#   'XGBoost_r194_BAG_L2': ['XGBoost_r194_BAG_L2'],
#   'ExtraTrees_r172_BAG_L2': ['ExtraTrees_r172_BAG_L2'],
#   'CatBoost_r69_BAG_L2': ['CatBoost_r69_BAG_L2'],
#   'NeuralNetTorch_r14_BAG_L2': ['NeuralNetTorch_r14_BAG_L2'],
#   'LightGBM_r161_BAG_L2': ['LightGBM_r161_BAG_L2'],
#   'CatBoost_r70_BAG_L2': ['CatBoost_r70_BAG_L2'],
#   'LightGBM_r196_BAG_L2': ['LightGBM_r196_BAG_L2'],
#   'RandomForest_r39_BAG_L2': ['RandomForest_r39_BAG_L2'],
#   'CatBoost_r167_BAG_L2': ['CatBoost_r167_BAG_L2'],
#   'NeuralNetTorch_r41_BAG_L2': ['NeuralNetTorch_r41_BAG_L2'],
#   'XGBoost_r98_BAG_L2': ['XGBoost_r98_BAG_L2'],
#   'LightGBM_r15_BAG_L2': ['LightGBM_r15_BAG_L2'],
#   'NeuralNetTorch_r158_BAG_L2': ['NeuralNetTorch_r158_BAG_L2'],
#   'CatBoost_r86_BAG_L2': ['CatBoost_r86_BAG_L2'],
#   'NeuralNetTorch_r197_BAG_L2': ['NeuralNetTorch_r197_BAG_L2'],
#   'CatBoost_r49_BAG_L2': ['CatBoost_r49_BAG_L2'],
#   'ExtraTrees_r49_BAG_L2': ['ExtraTrees_r49_BAG_L2'],
#   'LightGBM_r143_BAG_L2': ['LightGBM_r143_BAG_L2'],
#   'RandomForest_r127_BAG_L2': ['RandomForest_r127_BAG_L2'],
#   'RandomForest_r34_BAG_L2': ['RandomForest_r34_BAG_L2'],
#   'LightGBM_r94_BAG_L2': ['LightGBM_r94_BAG_L2'],
#   'NeuralNetTorch_r143_BAG_L2': ['NeuralNetTorch_r143_BAG_L2'],
#   'CatBoost_r128_BAG_L2': ['CatBoost_r128_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'LightGBMXT_BAG_L1': 10.166858673095703,
#   'LightGBM_BAG_L1': 9.434934854507446,
#   'RandomForestGini_BAG_L1': 5.37605619430542,
#   'RandomForestEntr_BAG_L1': 5.1333160400390625,
#   'CatBoost_BAG_L1': 403.8642451763153,
#   'ExtraTreesGini_BAG_L1': 3.392538070678711,
#   'ExtraTreesEntr_BAG_L1': 3.3169198036193848,
#   'XGBoost_BAG_L1': 57.87867188453674,
#   'NeuralNetTorch_BAG_L1': 225.1237461566925,
#   'LightGBMLarge_BAG_L1': 14.743253469467163,
#   'CatBoost_r177_BAG_L1': 285.453084230423,
#   'NeuralNetTorch_r79_BAG_L1': 305.3846206665039,
#   'LightGBM_r131_BAG_L1': 23.29143738746643,
#   'CatBoost_r9_BAG_L1': 173.33380484580994,
#   'LightGBM_r96_BAG_L1': 24.44967532157898,
#   'NeuralNetTorch_r22_BAG_L1': 372.3028817176819,
#   'XGBoost_r33_BAG_L1': 198.27208471298218,
#   'ExtraTrees_r42_BAG_L1': 5.95761775970459,
#   'CatBoost_r137_BAG_L1': 617.1467182636261,
#   'CatBoost_r13_BAG_L1': 1011.7464020252228,
#   'RandomForest_r195_BAG_L1': 13.162428617477417,
#   'LightGBM_r188_BAG_L1': 14.196528911590576,
#   'XGBoost_r89_BAG_L1': 87.83878636360168,
#   'NeuralNetTorch_r30_BAG_L1': 498.61898374557495,
#   'LightGBM_r130_BAG_L1': 11.810744762420654,
#   'NeuralNetTorch_r86_BAG_L1': 1624.4090435504913,
#   'CatBoost_r50_BAG_L1': 110.73527836799622,
#   'XGBoost_r194_BAG_L1': 12.74586534500122,
#   'ExtraTrees_r172_BAG_L1': 7.062150716781616,
#   'CatBoost_r69_BAG_L1': 474.3291256427765,
#   'NeuralNetTorch_r14_BAG_L1': 117.44842076301575,
#   'LightGBM_r161_BAG_L1': 44.86618995666504,
#   'CatBoost_r70_BAG_L1': 138.59128546714783,
#   'LightGBM_r196_BAG_L1': 87.45622420310974,
#   'RandomForest_r39_BAG_L1': 12.923516035079956,
#   'CatBoost_r167_BAG_L1': 186.6541874408722,
#   'NeuralNetTorch_r41_BAG_L1': 220.57360816001892,
#   'XGBoost_r98_BAG_L1': 121.1112129688263,
#   'LightGBM_r15_BAG_L1': 16.329261302947998,
#   'NeuralNetTorch_r158_BAG_L1': 1887.9014253616333,
#   'CatBoost_r86_BAG_L1': 464.1619849205017,
#   'NeuralNetTorch_r197_BAG_L1': 117.70741438865662,
#   'CatBoost_r49_BAG_L1': 158.7365918159485,
#   'ExtraTrees_r49_BAG_L1': 3.4595046043395996,
#   'LightGBM_r143_BAG_L1': 26.631285190582275,
#   'RandomForest_r127_BAG_L1': 16.312004327774048,
#   'RandomForest_r34_BAG_L1': 10.594020128250122,
#   'LightGBM_r94_BAG_L1': 13.921716928482056,
#   'NeuralNetTorch_r143_BAG_L1': 675.586375951767,
#   'CatBoost_r128_BAG_L1': 149.9234104156494,
#   'NeuralNetTorch_r31_BAG_L1': 370.75787687301636,
#   'ExtraTrees_r4_BAG_L1': 6.640263795852661,
#   'LightGBM_r30_BAG_L1': 30.846461296081543,
#   'XGBoost_r49_BAG_L1': 138.21419739723206,
#   'CatBoost_r5_BAG_L1': 463.8595144748688,
#   'NeuralNetTorch_r87_BAG_L1': 266.76483058929443,
#   'NeuralNetTorch_r71_BAG_L1': 106.439444065094,
#   'CatBoost_r143_BAG_L1': 166.91958951950073,
#   'ExtraTrees_r178_BAG_L1': 5.784873008728027,
#   'RandomForest_r166_BAG_L1': 5.391890287399292,
#   'XGBoost_r31_BAG_L1': 1052.116415977478,
#   'NeuralNetTorch_r185_BAG_L1': 849.9411804676056,
#   'CatBoost_r60_BAG_L1': 608.2983794212341,
#   'RandomForest_r15_BAG_L1': 13.07500171661377,
#   'LightGBM_r135_BAG_L1': 16.06972599029541,
#   'XGBoost_r22_BAG_L1': 87.33855986595154,
#   'CatBoost_r6_BAG_L1': 92.76696801185608,
#   'LightGBM_r121_BAG_L1': 43.34902238845825,
#   'CatBoost_r180_BAG_L1': 93.00947141647339,
#   'NeuralNetTorch_r76_BAG_L1': 450.2135729789734,
#   'ExtraTrees_r197_BAG_L1': 7.914001703262329,
#   'NeuralNetTorch_r121_BAG_L1': 2881.972811460495,
#   'RandomForest_r16_BAG_L1': 17.51062774658203,
#   'CatBoost_r12_BAG_L1': 486.7601284980774,
#   'NeuralNetTorch_r135_BAG_L1': 174.45726323127747,
#   'ExtraTrees_r126_BAG_L1': 3.423002004623413,
#   'NeuralNetTorch_r36_BAG_L1': 28.048686742782593,
#   'WeightedEnsemble_L2': 9.509388446807861,
#   'LightGBMXT_BAG_L2': 11.899513721466064,
#   'LightGBM_BAG_L2': 13.078174591064453,
#   'RandomForestGini_BAG_L2': 49.46101665496826,
#   'RandomForestEntr_BAG_L2': 43.6880419254303,
#   'CatBoost_BAG_L2': 88.48494911193848,
#   'ExtraTreesGini_BAG_L2': 8.79800009727478,
#   'ExtraTreesEntr_BAG_L2': 8.345812797546387,
#   'XGBoost_BAG_L2': 40.57899045944214,
#   'NeuralNetTorch_BAG_L2': 215.92218494415283,
#   'LightGBMLarge_BAG_L2': 21.958215475082397,
#   'CatBoost_r177_BAG_L2': 72.6111388206482,
#   'NeuralNetTorch_r79_BAG_L2': 317.3786895275116,
#   'LightGBM_r131_BAG_L2': 26.055453300476074,
#   'CatBoost_r9_BAG_L2': 120.18973278999329,
#   'LightGBM_r96_BAG_L2': 17.1987566947937,
#   'NeuralNetTorch_r22_BAG_L2': 365.31655383110046,
#   'XGBoost_r33_BAG_L2': 165.45796585083008,
#   'ExtraTrees_r42_BAG_L2': 44.58616924285889,
#   'CatBoost_r137_BAG_L2': 80.54362177848816,
#   'CatBoost_r13_BAG_L2': 356.9029026031494,
#   'RandomForest_r195_BAG_L2': 544.5859327316284,
#   'LightGBM_r188_BAG_L2': 15.413475513458252,
#   'XGBoost_r89_BAG_L2': 47.19827723503113,
#   'NeuralNetTorch_r30_BAG_L2': 447.3902168273926,
#   'LightGBM_r130_BAG_L2': 13.707312107086182,
#   'NeuralNetTorch_r86_BAG_L2': 1522.8788924217224,
#   'CatBoost_r50_BAG_L2': 42.126256704330444,
#   'XGBoost_r194_BAG_L2': 24.753365993499756,
#   'ExtraTrees_r172_BAG_L2': 55.12333631515503,
#   'CatBoost_r69_BAG_L2': 84.68002533912659,
#   'NeuralNetTorch_r14_BAG_L2': 145.86030292510986,
#   'LightGBM_r161_BAG_L2': 46.35294437408447,
#   'CatBoost_r70_BAG_L2': 72.21619057655334,
#   'LightGBM_r196_BAG_L2': 49.4634473323822,
#   'RandomForest_r39_BAG_L2': 510.7870593070984,
#   'CatBoost_r167_BAG_L2': 65.50471687316895,
#   'NeuralNetTorch_r41_BAG_L2': 232.86392998695374,
#   'XGBoost_r98_BAG_L2': 217.34991693496704,
#   'LightGBM_r15_BAG_L2': 17.29734468460083,
#   'NeuralNetTorch_r158_BAG_L2': 1834.89306306839,
#   'CatBoost_r86_BAG_L2': 185.347553730011,
#   'NeuralNetTorch_r197_BAG_L2': 176.05957007408142,
#   'CatBoost_r49_BAG_L2': 47.40203404426575,
#   'ExtraTrees_r49_BAG_L2': 8.839329481124878,
#   'LightGBM_r143_BAG_L2': 43.659435510635376,
#   'RandomForest_r127_BAG_L2': 619.3152923583984,
#   'RandomForest_r34_BAG_L2': 328.8409445285797,
#   'LightGBM_r94_BAG_L2': 12.09508204460144,
#   'NeuralNetTorch_r143_BAG_L2': 176.7443766593933,
#   'CatBoost_r128_BAG_L2': 34.56225085258484,
#   'WeightedEnsemble_L3': 9.32840347290039},
#  'model_pred_times': {'LightGBMXT_BAG_L1': 0.3379948139190674,
#   'LightGBM_BAG_L1': 0.2789943218231201,
#   'RandomForestGini_BAG_L1': 3.5243630409240723,
#   'RandomForestEntr_BAG_L1': 3.4014780521392822,
#   'CatBoost_BAG_L1': 0.18098926544189453,
#   'ExtraTreesGini_BAG_L1': 3.71695613861084,
#   'ExtraTreesEntr_BAG_L1': 3.7156052589416504,
#   'XGBoost_BAG_L1': 0.3696303367614746,
#   'NeuralNetTorch_BAG_L1': 0.4891507625579834,
#   'LightGBMLarge_BAG_L1': 0.4329972267150879,
#   'CatBoost_r177_BAG_L1': 0.14500808715820312,
#   'NeuralNetTorch_r79_BAG_L1': 0.5657374858856201,
#   'LightGBM_r131_BAG_L1': 1.5719964504241943,
#   'CatBoost_r9_BAG_L1': 0.1460413932800293,
#   'LightGBM_r96_BAG_L1': 1.4741806983947754,
#   'NeuralNetTorch_r22_BAG_L1': 0.6110854148864746,
#   'XGBoost_r33_BAG_L1': 1.5749962329864502,
#   'ExtraTrees_r42_BAG_L1': 3.429574489593506,
#   'CatBoost_r137_BAG_L1': 0.16904950141906738,
#   'CatBoost_r13_BAG_L1': 0.34599995613098145,
#   'RandomForest_r195_BAG_L1': 3.299844741821289,
#   'LightGBM_r188_BAG_L1': 0.4999964237213135,
#   'XGBoost_r89_BAG_L1': 0.4160001277923584,
#   'NeuralNetTorch_r30_BAG_L1': 0.7185420989990234,
#   'LightGBM_r130_BAG_L1': 0.3269932270050049,
#   'NeuralNetTorch_r86_BAG_L1': 2.505122423171997,
#   'CatBoost_r50_BAG_L1': 0.1180112361907959,
#   'XGBoost_r194_BAG_L1': 0.14400291442871094,
#   'ExtraTrees_r172_BAG_L1': 3.3132505416870117,
#   'CatBoost_r69_BAG_L1': 0.1990504264831543,
#   'NeuralNetTorch_r14_BAG_L1': 0.3419036865234375,
#   'LightGBM_r161_BAG_L1': 2.133798599243164,
#   'CatBoost_r70_BAG_L1': 0.13504385948181152,
#   'LightGBM_r196_BAG_L1': 5.900008916854858,
#   'RandomForest_r39_BAG_L1': 3.293276071548462,
#   'CatBoost_r167_BAG_L1': 0.10100507736206055,
#   'NeuralNetTorch_r41_BAG_L1': 0.4194490909576416,
#   'XGBoost_r98_BAG_L1': 2.4329946041107178,
#   'LightGBM_r15_BAG_L1': 0.9218792915344238,
#   'NeuralNetTorch_r158_BAG_L1': 3.429569959640503,
#   'CatBoost_r86_BAG_L1': 0.1939997673034668,
#   'NeuralNetTorch_r197_BAG_L1': 0.3592095375061035,
#   'CatBoost_r49_BAG_L1': 0.056005001068115234,
#   'ExtraTrees_r49_BAG_L1': 3.6882667541503906,
#   'LightGBM_r143_BAG_L1': 1.1879940032958984,
#   'RandomForest_r127_BAG_L1': 3.1507954597473145,
#   'RandomForest_r34_BAG_L1': 3.0100018978118896,
#   'LightGBM_r94_BAG_L1': 0.6546535491943359,
#   'NeuralNetTorch_r143_BAG_L1': 0.7960031032562256,
#   'CatBoost_r128_BAG_L1': 0.14703655242919922,
#   'NeuralNetTorch_r31_BAG_L1': 0.4586009979248047,
#   'ExtraTrees_r4_BAG_L1': 3.1635260581970215,
#   'LightGBM_r30_BAG_L1': 1.7225027084350586,
#   'XGBoost_r49_BAG_L1': 0.6970012187957764,
#   'CatBoost_r5_BAG_L1': 0.15400147438049316,
#   'NeuralNetTorch_r87_BAG_L1': 0.45929813385009766,
#   'NeuralNetTorch_r71_BAG_L1': 0.33553099632263184,
#   'CatBoost_r143_BAG_L1': 0.08300089836120605,
#   'ExtraTrees_r178_BAG_L1': 3.3202226161956787,
#   'RandomForest_r166_BAG_L1': 3.45934796333313,
#   'XGBoost_r31_BAG_L1': 2.593003273010254,
#   'NeuralNetTorch_r185_BAG_L1': 0.5822451114654541,
#   'CatBoost_r60_BAG_L1': 0.2440013885498047,
#   'RandomForest_r15_BAG_L1': 3.2275893688201904,
#   'LightGBM_r135_BAG_L1': 0.387998104095459,
#   'XGBoost_r22_BAG_L1': 0.4610018730163574,
#   'CatBoost_r6_BAG_L1': 0.10398721694946289,
#   'LightGBM_r121_BAG_L1': 2.0829994678497314,
#   'CatBoost_r180_BAG_L1': 0.10344457626342773,
#   'NeuralNetTorch_r76_BAG_L1': 0.9354910850524902,
#   'ExtraTrees_r197_BAG_L1': 3.3983547687530518,
#   'NeuralNetTorch_r121_BAG_L1': 6.842993974685669,
#   'RandomForest_r16_BAG_L1': 3.3011717796325684,
#   'CatBoost_r12_BAG_L1': 0.22101593017578125,
#   'NeuralNetTorch_r135_BAG_L1': 0.6885793209075928,
#   'ExtraTrees_r126_BAG_L1': 3.5755088329315186,
#   'NeuralNetTorch_r36_BAG_L1': 0.40189290046691895,
#   'WeightedEnsemble_L2': 0.014999628067016602,
#   'LightGBMXT_BAG_L2': 0.19199538230895996,
#   'LightGBM_BAG_L2': 0.18503689765930176,
#   'RandomForestGini_BAG_L2': 5.4690752029418945,
#   'RandomForestEntr_BAG_L2': 5.335308790206909,
#   'CatBoost_BAG_L2': 0.09902024269104004,
#   'ExtraTreesGini_BAG_L2': 5.59553599357605,
#   'ExtraTreesEntr_BAG_L2': 5.585432052612305,
#   'XGBoost_BAG_L2': 0.7570013999938965,
#   'NeuralNetTorch_BAG_L2': 2.0010111331939697,
#   'LightGBMLarge_BAG_L2': 0.2562556266784668,
#   'CatBoost_r177_BAG_L2': 0.08709430694580078,
#   'NeuralNetTorch_r79_BAG_L2': 2.154505491256714,
#   'LightGBM_r131_BAG_L2': 0.46642541885375977,
#   'CatBoost_r9_BAG_L2': 0.12700939178466797,
#   'LightGBM_r96_BAG_L2': 0.3841836452484131,
#   'NeuralNetTorch_r22_BAG_L2': 2.1243088245391846,
#   'XGBoost_r33_BAG_L2': 1.3370020389556885,
#   'ExtraTrees_r42_BAG_L2': 5.398642539978027,
#   'CatBoost_r137_BAG_L2': 0.09301185607910156,
#   'CatBoost_r13_BAG_L2': 0.10901093482971191,
#   'RandomForest_r195_BAG_L2': 5.511815071105957,
#   'LightGBM_r188_BAG_L2': 0.26200246810913086,
#   'XGBoost_r89_BAG_L2': 0.7829971313476562,
#   'NeuralNetTorch_r30_BAG_L2': 2.2552711963653564,
#   'LightGBM_r130_BAG_L2': 0.19899964332580566,
#   'NeuralNetTorch_r86_BAG_L2': 3.805344581604004,
#   'CatBoost_r50_BAG_L2': 0.1030125617980957,
#   'XGBoost_r194_BAG_L2': 0.2750051021575928,
#   'ExtraTrees_r172_BAG_L2': 5.295984983444214,
#   'CatBoost_r69_BAG_L2': 0.093994140625,
#   'NeuralNetTorch_r14_BAG_L2': 1.900136947631836,
#   'LightGBM_r161_BAG_L2': 0.7879989147186279,
#   'CatBoost_r70_BAG_L2': 0.11700820922851562,
#   'LightGBM_r196_BAG_L2': 2.116000175476074,
#   'RandomForest_r39_BAG_L2': 5.458261728286743,
#   'CatBoost_r167_BAG_L2': 0.09325957298278809,
#   'NeuralNetTorch_r41_BAG_L2': 1.9826347827911377,
#   'XGBoost_r98_BAG_L2': 1.2659142017364502,
#   'LightGBM_r15_BAG_L2': 0.28800177574157715,
#   'NeuralNetTorch_r158_BAG_L2': 5.568918943405151,
#   'CatBoost_r86_BAG_L2': 0.1060025691986084,
#   'NeuralNetTorch_r197_BAG_L2': 1.8794941902160645,
#   'CatBoost_r49_BAG_L2': 0.08632397651672363,
#   'ExtraTrees_r49_BAG_L2': 5.609248876571655,
#   'LightGBM_r143_BAG_L2': 0.5270013809204102,
#   'RandomForest_r127_BAG_L2': 5.337252855300903,
#   'RandomForest_r34_BAG_L2': 5.052865982055664,
#   'LightGBM_r94_BAG_L2': 0.23630571365356445,
#   'NeuralNetTorch_r143_BAG_L2': 2.304753541946411,
#   'CatBoost_r128_BAG_L2': 0.10018324851989746,
#   'WeightedEnsemble_L3': 0.015001296997070312},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r34_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r4_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r30_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r49_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r5_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r87_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r71_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r143_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r178_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r166_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_r31_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r185_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r60_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r15_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r6_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r180_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r76_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r197_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r121_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r16_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r12_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r135_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r126_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetTorch_r36_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r30_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r130_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r86_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r50_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r194_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r172_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r69_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r14_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r161_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r70_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r196_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r39_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r167_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r41_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r98_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r15_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r158_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r86_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r197_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r49_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r49_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r143_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r127_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForest_r34_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r94_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r143_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r128_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val eval_metric  pred_time_val  \
#  0           WeightedEnsemble_L2   0.976305     roc_auc       8.899642
#  1           WeightedEnsemble_L3   0.976303     roc_auc     123.822227
#  2           CatBoost_r13_BAG_L2   0.976252     roc_auc     113.488861
#  3           CatBoost_r86_BAG_L2   0.976215     roc_auc     113.485852
#  4            CatBoost_r9_BAG_L2   0.976195     roc_auc     113.506859
#  ..                          ...        ...         ...            ...
#  124     RandomForest_r15_BAG_L1   0.970274     roc_auc       3.227589
#  125     RandomForest_r39_BAG_L1   0.969649     roc_auc       3.293276
#  126    RandomForest_r195_BAG_L1   0.968985     roc_auc       3.299845
#  127     RandomForest_r16_BAG_L1   0.968302     roc_auc       3.301172
#  128  NeuralNetTorch_r158_BAG_L2   0.963984     roc_auc     118.948769
#
#           fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0     2803.581948                0.015000           9.509388            2
#  1    21069.609257                0.015001           9.328403            3
#  2    19906.354107                0.109011         356.902903            2
#  3    19734.798758                0.106003         185.347554            2
#  4    19669.640937                0.127009         120.189733            2
#  ..            ...                     ...                ...          ...
#  124     13.075002                3.227589          13.075002            1
#  125     12.923516                3.293276          12.923516            1
#  126     13.162429                3.299845          13.162429            1
#  127     17.510628                3.301172          17.510628            1
#  128  21384.344268                5.568919        1834.893063            2
#
#       can_infer  fit_order
#  0         True         78
#  1         True        129
#  2         True         98
#  3         True        119
#  4         True         92
#  ..         ...        ...
#  124       True         64
#  125       True         35
#  126       True         21
#  127       True         73
#  128       True        118
#
#  [129 rows x 10 columns]}

# %%
# Get the leaderboard to see the performance of the models
leaderboard = predictor.leaderboard(silent=True)

# Print the leaderboard for reference
leaderboard
# Out:
#                           model  score_val eval_metric  pred_time_val  \
# 0           WeightedEnsemble_L2   0.976305     roc_auc       8.899642
# 1           WeightedEnsemble_L3   0.976303     roc_auc     123.822227
# 2           CatBoost_r13_BAG_L2   0.976252     roc_auc     113.488861
# 3           CatBoost_r86_BAG_L2   0.976215     roc_auc     113.485852
# 4            CatBoost_r9_BAG_L2   0.976195     roc_auc     113.506859
# ..                          ...        ...         ...            ...
# 124     RandomForest_r15_BAG_L1   0.970274     roc_auc       3.227589
# 125     RandomForest_r39_BAG_L1   0.969649     roc_auc       3.293276
# 126    RandomForest_r195_BAG_L1   0.968985     roc_auc       3.299845
# 127     RandomForest_r16_BAG_L1   0.968302     roc_auc       3.301172
# 128  NeuralNetTorch_r158_BAG_L2   0.963984     roc_auc     118.948769
#
#          fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0     2803.581948                0.015000           9.509388            2
# 1    21069.609257                0.015001           9.328403            3
# 2    19906.354107                0.109011         356.902903            2
# 3    19734.798758                0.106003         185.347554            2
# 4    19669.640937                0.127009         120.189733            2
# ..            ...                     ...                ...          ...
# 124     13.075002                3.227589          13.075002            1
# 125     12.923516                3.293276          12.923516            1
# 126     13.162429                3.299845          13.162429            1
# 127     17.510628                3.301172          17.510628            1
# 128  21384.344268                5.568919        1834.893063            2
#
#      can_infer  fit_order
# 0         True         78
# 1         True        129
# 2         True         98
# 3         True        119
# 4         True         92
# ..         ...        ...
# 124       True         64
# 125       True         35
# 126       True         21
# 127       True         73
# 128       True        118
#
# [129 rows x 10 columns]

# %%
# Get the top 10 models based on the leaderboard
top_10_models = leaderboard['model'].head(10).tolist()
top_10_models
# Out:
# ['WeightedEnsemble_L2',
#  'WeightedEnsemble_L3',
#  'CatBoost_r13_BAG_L2',
#  'CatBoost_r86_BAG_L2',
#  'CatBoost_r9_BAG_L2',
#  'CatBoost_r70_BAG_L2',
#  'CatBoost_r69_BAG_L2',
#  'CatBoost_r49_BAG_L2',
#  'CatBoost_r137_BAG_L2',
#  'CatBoost_BAG_L2']

# %%
# Iterate through the top 10 models and print their hyperparameters
for model in top_10_models:
    hyperparameters = predictor.info()['model_info'][model]['hyperparameters']
    print(f"Model: {model}")
    print("Hyperparameters:")
    print(hyperparameters)
    print("-" * 50)
# Out:
# Model: WeightedEnsemble_L2
# Hyperparameters:
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: WeightedEnsemble_L3
# Hyperparameters:
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r13_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r86_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r9_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r70_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r69_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r49_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_r137_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------

# %%
# Get details of the best model
best_model = predictor.get_model_best()
print(f"Best Model: {best_model}")

# Get model hyperparameters and other info
best_model_info = predictor.info()
print(best_model_info)
# Out:
# Best Model: WeightedEnsemble_L2
# C:\Users\Hi\AppData\Local\Temp\ipykernel_13936\3617745900.py:2: DeprecationWarning: `get_model_best` has been deprecated and will be removed in version 1.2. Please use `model_best` instead. This will raise an error in the future!
#   best_model = predictor.get_model_best()
# {'path': 'AutogluonModels\\ag-20241102_072842', 'label': 'Depression', 'random_state': 0, 'version': '1.1.1', 'features': ['id', 'Name', 'Gender', 'Age', 'City', 'Working Professional or Student', 'Profession', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction', 'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness'], 'feature_metadata_in': <autogluon.common.features.feature_metadata.FeatureMetadata object at 0x00000274B9A4EC10>, 'time_fit_preprocessing': 0.5804619789123535, 'time_fit_training': 29652.379621505737, 'time_fit_total': 29652.96008348465, 'time_limit': 29642.286379814148, 'time_train_start': 1730542480.7103362, 'num_rows_train': 140700, 'num_cols_train': 19, 'num_rows_val': None, 'num_classes': 2, 'problem_type': 'binary', 'eval_metric': 'roc_auc', 'best_model': 'WeightedEnsemble_L2', 'best_model_score_val': 0.9763045794999051, 'best_model_stack_level': 2, 'num_models_trained': 129, 'num_bag_folds': 8, 'max_stack_level': 3, 'max_core_stack_level': 2, 'model_info': {'LightGBMXT_BAG_L1': {'name': 'LightGBMXT_BAG_L1', 'model_type': 'StackerEnsembleModel', 'problem_type': 'binary', 'eval_metric': 'roc_auc', 'stopping_metric': 'log_loss', 'fit_time': 10.166858673095703, 'num_classes': 2, 'quantile_levels': None, 'predict_time': 0.3379948139190674, 'val_score': 0.9750151855526674, 'hyperparameters': {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}, 'hyperparameters_fit': {}, 'hyperparameters_nondefault': [], 'ag_args_fit': {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}, 'num_features': 19, 'features': ['City', 'Have you ever had suicidal thoughts ?', 'Degree', 'Working Professional or Student', 'Profession', 'Work/Study Hours', 'Academic Pressure', 'Financial Stress', 'Work Pressure', 'Study Satisfaction', 'Gender', 'Family History of Mental Illness', 'id', 'Sleep Duration', 'CGPA', 'Dietary Habits', 'Age', 'Name', 'Job Satisfaction'], 'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata object at 0x00000274C56C68E0>, 'memory_size': 3310, 'compile_time': None, 'is_initialized': True, 'is_fit': True, 'is_valid': True, 'can_infer': True, 'bagged_info': {'child_model_type': 'LGBModel', 'num_child_models': 8, 'child_model_names': ['S1F2', 'S1F1', 'S1F3', 'S1F4', 'S1F5', 'S1F6', 'S1F7', 'S1F8'], '_n_repeats': 1, '_k_per_n_repeat': [8], '_random_state': 1, 'low_memory': True, 'bagged_mode': True, 'max_memory_size': 7065549, 'min_memory_size': 976686, 'child_hyperparameters': {'learning_rate': 0.05, 'extra_trees': True}, 'child_hyperparameters_fit': {'num_boost_round': 227}, 'child_ag_args_fit': {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'num_cpus': 10, 'num_gpus': 0, 'memory_ratio': 0.8}}, 'stacker_info': {'num_base_models': 0, 'base_model_names': []}, 'children_info': {'S1F2': {'name': 'S1F2', 'model_type': 'LGBModel', 'problem_type': 'binary', 'eval_metric': 'roc_auc', 'stopping_metric': 'log_loss', 'fit_time': 1.2519984245300293, 'num_classes': 2, 'quantile_levels': None, 'predict_time': 0.04400038719177246, 'val_score': 0.9736052691628848, 'hyperparameters': {'learning_rate': 0.05, 'extra_trees': True}, 'hyperparameters_fit': {'num_boost_round': 20 ...

# %%
# Feature importance
feature_importance = predictor.feature_importance(train_df)
print("Feature Importance:\n", feature_importance)
# Out:
# Computing feature importance via permutation shuffling for 19 features using 5000 rows with 5 shuffle sets...
# 	337.33s	= Expected runtime (67.47s per shuffle set)
# 	170.28s	= Actual runtime (Completed 5 of 5 shuffle sets)
# Feature Importance:
#                                         importance    stddev       p_value  n  \
# Age                                      0.090374  0.006322  2.854135e-06  5
# Have you ever had suicidal thoughts ?    0.026139  0.002701  1.349801e-05  5
# Academic Pressure                        0.013776  0.002340  9.624049e-05  5
# Financial Stress                         0.008467  0.001236  5.295719e-05  5
# Work Pressure                            0.006485  0.001157  1.167514e-04  5
# Job Satisfaction                         0.005635  0.000780  4.298553e-05  5
# Work/Study Hours                         0.003965  0.000394  1.157617e-05  5
# Name                                     0.003843  0.000497  3.271331e-05  5
# Profession                               0.003524  0.000877  4.236754e-04  5
# Dietary Habits                           0.003052  0.000561  1.306617e-04  5
# City                                     0.002175  0.000178  5.366614e-06  5
# Degree                                   0.001824  0.000354  1.615164e-04  5
# Sleep Duration                           0.001244  0.000185  5.678081e-05  5
# Study Satisfaction                       0.001068  0.000105  1.089957e-05  5
# id                                       0.000595  0.000026  4.714958e-07  5
# Family History of Mental Illness         0.000495  0.000197  2.478738e-03  5
# CGPA                                     0.000445  0.000121  5.888473e-04  5
# Gender                                   0.000317  0.000066  2.159230e-04  5
# Working Professional or Student          0.000204  0.000147  1.782813e-02  5
#
#                                        p99_high   p99_low
# Age                                    0.103390  0.077357
# Have you ever had suicidal thoughts ?  0.031701  0.020576
# Academic Pressure                      0.018595  0.008957
# Financial Stress                       0.011011  0.005922
# Work Pressure                          0.008868  0.004102
# Job Satisfaction                       0.007242  0.004029
# Work/Study Hours                       0.004777  0.003153
# Name                                   0.004866  0.002821
# Profession                             0.005329  0.001720
# Dietary Habits                         0.004206  0.001898
# City                                   0.002542  0.001808
# Degree                                 0.002552  0.001095
# Sleep Duration                         0.001624  0.000863
# Study Satisfaction                     0.001284  0.000853
# id                                     0.000649  0.000540
# Family History of Mental Illness       0.000901  0.000089
# CGPA                                   0.000693  0.000197
# Gender                                 0.000453  0.000180
# Working Professional or Student        0.000507 -0.000098

# %%
sample_submission_df = pd.read_csv("sample_submission.csv")
sample_submission_df.head()
# Out:
#        id  Depression
# 0  140700           0
# 1  140701           0
# 2  140702           0
# 3  140703           0
# 4  140704           0

# %%
# Make predictions on the test data
y_pred_predictor = predictor.predict(test_df)

# Create the submission file
sample_submission_df['Depression'] = y_pred_predictor
sample_submission_df.head()
# Out:
#        id  Depression
# 0  140700           0
# 1  140701           0
# 2  140702           0
# 3  140703           1
# 4  140704           0

# %%
sample_submission_df.to_csv('27_01 - Submission.csv', index=False)
